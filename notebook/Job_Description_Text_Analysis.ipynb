# %%
import spacy
from textacy import preprocessing
from textacy import extract
import pandas as pd
from spacy import displacy
import re
import numpy as np
from sklearn.cluster import KMeans
import pytextrank

# %%
nlp = spacy.load("en_core_web_lg")
nlp.add_pipe("textrank")

# %%
ruler = nlp.add_pipe("entity_ruler", before="ner")
#nlp.remove_pipe("entity_ruler")

# %%
patterns = [
    {"label": "SKILL", "pattern": [{"POS": "VERB", "IS_SENT_START": True},  
                                   {"SPACY": True, "OP": "*"}, {"POS": "NOUN"}]},
    {"label": "JOB", "pattern": [{"POS": "NOUN", "LEMMA": {"IN" : ["engineer", "designer", "product management"]}}]},
    {"label": "PROD", "pattern": [{"TEXT": "seeking"},{"TEXT": "S3"}]}
]

ruler.add_patterns(patterns)

doc3 = nlp("Description seeking, seeking experienced, experienced product, designer engineer product leader, leader join, join Boston, MA office, office lead, lead product, product management, management AWS3, AWS newest, newest hybrid, hybrid storage, storage service, AWS Outposts, Outposts provide, provide fully, fully managed, managed AWS, AWS infrastructure, infrastructure services, services customers")
print([(ent.text, ent.label_) for ent in doc3.ents])
# Out:
# [('designer', 'JOB'), ('engineer', 'JOB'), ('Boston', 'GPE'), ('MA', 'ORG'), ('AWS3', 'ORG'), ('AWS', 'ORG'), ('AWS Outposts', 'ORG'), ('Outposts', 'ORG'), ('AWS', 'ORG')]

# %%
displacy.render(doc3, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Description seeking, seeking experienced, experienced product,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     designer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">JOB</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     engineer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">JOB</span>
# </mark>
#  product leader, leader join, join
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Boston
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  office, office lead, lead product, product management, management
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AWS3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AWS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  newest, newest hybrid, hybrid storage, storage service,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AWS Outposts
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Outposts
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  provide, provide fully, fully managed, managed
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AWS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , AWS infrastructure, infrastructure services, services customers</div></span>

# %%
def remove_stop_words(text: str):
    
    doc = nlp(text)
    tokens = [token.text for token in doc if not token.is_stop]
    return " ".join(tokens)

# %%
def remove_new_line(text: str):
    return text.replace("\n", " ")

# %%
preproc = preprocessing.make_pipeline(
    remove_new_line,
    preprocessing.remove.html_tags,
    remove_stop_words,
    preprocessing.normalize.whitespace, 
    preprocessing.replace.urls, 
    preprocessing.replace.numbers, 
    preprocessing.normalize.unicode
)

# %%
lnkjobs = pd.read_csv("../data/linkedin_jobs.csv")
lnkjobs
# Out:
#     index                                            subject  \
# 0       0        Principal Product Manager - Technical - AWS
# 1       1  Principal Product Manager Technical, Amazon De...
# 2       2                           Sr. Data Product Manager
# 3       3  Senior Principal Product Manager (REMOTE ELIGI...
# 4       4   Principal Product Manager, Cloud-Native Platform
# 5       5  Senior Product Manager, Multi-Cloud Commerce -...
# 6       6                   Principal Product Manager - Tech
# 7       7                              Group Product Manager
# 8       8                          Principal Product Manager
# 9       9                             Senior Product Manager
# 10     10               Product Manager, Data Infrastructure
# 11     11                    Product Manager - Data Delivery
# 12     12  Senior/Principal Product Manager Cloud Native ...
# 13     13                             Senior Product Manager
# 14     14                               Lead Product Manager
# 15     15                          Technical Product Manager
# 16     16      Sr. Product Manager, Technical, Amazon Athena
# 17     17                     Principal Product Manager Tech
# 18     18                           Senior Director, Product
# 19     19             Senior Product Manager - Data Platform
#
#                                                   url  \
# 0   https://www.linkedin.com/jobs/view/2600123751/...
# 1   https://www.linkedin.com/jobs/view/2798027544/...
# 2   https://www.linkedin.com/jobs/view/2787722444/...
# 3   https://www.linkedin.com/jobs/view/2799481430/...
# 4   https://www.linkedin.com/jobs/view/2802975863/...
# 5   https://www.linkedin.com/jobs/view/2780771184/...
# 6   https://www.linkedin.com/jobs/view/2798052149/...
# 7   https://www.linkedin.com/jobs/view/2801103520/...
# 8   https://www.linkedin.com/jobs/view/2807025455/...
# 9   https://www.linkedin.com/jobs/view/2793489860/...
# 10  https://www.linkedin.com/jobs/view/2798570529/...
# 11  https://www.linkedin.com/jobs/view/2805671651/...
# 12  https://www.linkedin.com/jobs/view/2784476506/...
# 13  https://www.linkedin.com/jobs/view/2797814260/...
# 14  https://www.linkedin.com/jobs/view/2789649615/...
# 15  https://www.linkedin.com/jobs/view/2796283396/...
# 16  https://www.linkedin.com/jobs/view/2797251260/...
# 17  https://www.linkedin.com/jobs/view/2797280753/...
# 18  https://www.linkedin.com/jobs/view/2804744863/...
# 19  https://www.linkedin.com/jobs/view/2787892330/...
#
#                                              job_desc
# 0   About the job\nDescription\n\nWe’re seeking an...
# 1   About the job\nDescription\n\nAWS External Sec...
# 2   About the job\nAbout CyberArk:\nCyberArk (NASD...
# 3   About the job\nAbout VERITAS\n\nVeritas solves...
# 4   About the job\nJob Description:\n\nPrincipal P...
# 5   About the job\nWhy will you enjoy this new opp...
# 6   About the job\nDescription\n\nAre you passiona...
# 7   About the job\nCoinbase has built the world's ...
# 8   About the job\nDescription:\nOverview\n\nPerch...
# 9   About the job\nDefine the Future of Work\nAs a...
# 10  About the job\nOver the coming years, biotech ...
# 11  About the job\nCambridge Mobile Telematics (CM...
# 12  About the job\nAs a Senior/Principal Product M...
# 13  About the job\nDo well by doing good.\n\nDo yo...
# 14  About the job\nOpentext - The Information Comp...
# 15  About the job\nWe are looking for a Technical ...
# 16  About the job\nJob Summary\n\nDESCRIPTION\n\nW...
# 17  About the job\nJob Summary\n\nDESCRIPTION\n\nA...
# 18  About the job\nThe Product team at Klaviyo is ...
# 19  About the job\nSophos is a worldwide leader in...

# %%
lnkjobs["clean_job_desc"] = lnkjobs["job_desc"].map(preproc)
lnkjobs["nlp"] = lnkjobs["job_desc"].map(nlp)
lnkjobs
# Out:
#     index                                            subject  \
# 0       0        Principal Product Manager - Technical - AWS
# 1       1  Principal Product Manager Technical, Amazon De...
# 2       2                           Sr. Data Product Manager
# 3       3  Senior Principal Product Manager (REMOTE ELIGI...
# 4       4   Principal Product Manager, Cloud-Native Platform
# 5       5  Senior Product Manager, Multi-Cloud Commerce -...
# 6       6                   Principal Product Manager - Tech
# 7       7                              Group Product Manager
# 8       8                          Principal Product Manager
# 9       9                             Senior Product Manager
# 10     10               Product Manager, Data Infrastructure
# 11     11                    Product Manager - Data Delivery
# 12     12  Senior/Principal Product Manager Cloud Native ...
# 13     13                             Senior Product Manager
# 14     14                               Lead Product Manager
# 15     15                          Technical Product Manager
# 16     16      Sr. Product Manager, Technical, Amazon Athena
# 17     17                     Principal Product Manager Tech
# 18     18                           Senior Director, Product
# 19     19             Senior Product Manager - Data Platform
#
#                                                   url  \
# 0   https://www.linkedin.com/jobs/view/2600123751/...
# 1   https://www.linkedin.com/jobs/view/2798027544/...
# 2   https://www.linkedin.com/jobs/view/2787722444/...
# 3   https://www.linkedin.com/jobs/view/2799481430/...
# 4   https://www.linkedin.com/jobs/view/2802975863/...
# 5   https://www.linkedin.com/jobs/view/2780771184/...
# 6   https://www.linkedin.com/jobs/view/2798052149/...
# 7   https://www.linkedin.com/jobs/view/2801103520/...
# 8   https://www.linkedin.com/jobs/view/2807025455/...
# 9   https://www.linkedin.com/jobs/view/2793489860/...
# 10  https://www.linkedin.com/jobs/view/2798570529/...
# 11  https://www.linkedin.com/jobs/view/2805671651/...
# 12  https://www.linkedin.com/jobs/view/2784476506/...
# 13  https://www.linkedin.com/jobs/view/2797814260/...
# 14  https://www.linkedin.com/jobs/view/2789649615/...
# 15  https://www.linkedin.com/jobs/view/2796283396/...
# 16  https://www.linkedin.com/jobs/view/2797251260/...
# 17  https://www.linkedin.com/jobs/view/2797280753/...
# 18  https://www.linkedin.com/jobs/view/2804744863/...
# 19  https://www.linkedin.com/jobs/view/2787892330/...
#
#                                              job_desc  \
# 0   About the job\nDescription\n\nWe’re seeking an...
# 1   About the job\nDescription\n\nAWS External Sec...
# 2   About the job\nAbout CyberArk:\nCyberArk (NASD...
# 3   About the job\nAbout VERITAS\n\nVeritas solves...
# 4   About the job\nJob Description:\n\nPrincipal P...
# 5   About the job\nWhy will you enjoy this new opp...
# 6   About the job\nDescription\n\nAre you passiona...
# 7   About the job\nCoinbase has built the world's ...
# 8   About the job\nDescription:\nOverview\n\nPerch...
# 9   About the job\nDefine the Future of Work\nAs a...
# 10  About the job\nOver the coming years, biotech ...
# 11  About the job\nCambridge Mobile Telematics (CM...
# 12  About the job\nAs a Senior/Principal Product M...
# 13  About the job\nDo well by doing good.\n\nDo yo...
# 14  About the job\nOpentext - The Information Comp...
# 15  About the job\nWe are looking for a Technical ...
# 16  About the job\nJob Summary\n\nDESCRIPTION\n\nW...
# 17  About the job\nJob Summary\n\nDESCRIPTION\n\nA...
# 18  About the job\nThe Product team at Klaviyo is ...
# 19  About the job\nSophos is a worldwide leader in...
#
#                                        clean_job_desc  \
# 0   job Description seeking experienced product le...
# 1   job Description AWS External Security Services...
# 2   job CyberArk : CyberArk ( NASDAQ : CYBR ) glob...
# 3   job VERITAS Veritas solves . industry - leadin...
# 4   job Job Description : Principal Product Manage...
# 5   job enjoy new opportunity ? VMware leader virt...
# 6   job Description passionate Artificial Intellig...
# 7   job Coinbase built world leading compliant cry...
# 8   job Description : Overview Perch new kind dire...
# 9   job Define Future Work thought leader industry...
# 10  job coming years , biotech fundamentally rewri...
# 11  job Cambridge Mobile Telematics ( CMT ) missio...
# 12  job Senior / Principal Product Manager Nutanix...
# 13  job good . wake morning excited work ? want en...
# 14  job Opentext - Information Company Information...
# 15  job looking Technical Product Manager previous...
# 16  job Job Summary DESCRIPTION Want work cutting ...
# 17  job Job Summary DESCRIPTION Amazon , working c...
# 18  job Product team Klaviyo continuously looking ...
# 19  job Sophos worldwide leader - generation cyber...
#
#                                                   nlp
# 0   (About, the, job, \n, Description, \n\n, We, ’...
# 1   (About, the, job, \n, Description, \n\n, AWS, ...
# 2   (About, the, job, \n, About, CyberArk, :, \n, ...
# 3   (About, the, job, \n, About, VERITAS, \n\n, Ve...
# 4   (About, the, job, \n, Job, Description, :, \n\...
# 5   (About, the, job, \n, Why, will, you, enjoy, t...
# 6   (About, the, job, \n, Description, \n\n, Are, ...
# 7   (About, the, job, \n, Coinbase, has, built, th...
# 8   (About, the, job, \n, Description, :, \n, Over...
# 9   (About, the, job, \n, Define, the, Future, of,...
# 10  (About, the, job, \n, Over, the, coming, years...
# 11  (About, the, job, \n, Cambridge, Mobile, Telem...
# 12  (About, the, job, \n, As, a, Senior, /, Princi...
# 13  (About, the, job, \n, Do, well, by, doing, goo...
# 14  (About, the, job, \n, Opentext, -, The, Inform...
# 15  (About, the, job, \n, We, are, looking, for, a...
# 16  (About, the, job, \n, Job, Summary, \n\n, DESC...
# 17  (About, the, job, \n, Job, Summary, \n\n, DESC...
# 18  (About, the, job, \n, The, Product, team, at, ...
# 19  (About, the, job, \n, Sophos, is, a, worldwide...

# %%
lnkjobs["clean_job_desc"][0]

results = [x for x in lnkjobs['clean_job_desc']]
doc = nlp(' '.join(results))

# %%
ngrams = list(extract.basics.ngrams(doc, 2, min_freq=1))

print(ngrams)
# Out:
# [job Description, Description seeking, seeking experienced, experienced product, product leader, leader join, join Boston, MA office, office lead, lead product, product management, management AWS, AWS newest, newest hybrid, hybrid storage, storage service, AWS Outposts, Outposts provide, provide fully, fully managed, managed AWS, AWS infrastructure, infrastructure services, services customers, premises data, data centers, Amazon S3, S3 Outposts, provides hybrid, hybrid object, object storage, storage enabling, enabling customers, customers store, store retrieve, retrieve data, premises S3, S3 programming, programming model, model features, team responsible, responsible delivering, delivering hybrid, hybrid storage, storage platform, platform Outposts, help shape, shape object, object storage, storage generation, generation hybrid, hybrid computing, computing platform, Product Management, Management AWS, AWS opportunity, opportunity collaborate, collaborate engineering, business development, development teams, looking entrepreneurial, entrepreneurial product, product leader, leader passionate, passionate delivering, delivering solutions, solutions customers, customers excited, excited growing, growing new, new AWS, AWS business, Successful candidates, candidates able, able build, build strategic, strategic roadmap, roadmap business, dive technical, technical details, details working, working closely, closely engineering, engineering team, team drive, drive delivery, delivery features, features delight, delight customers, joining experienced, experienced team, team engineers, engineers product, product managers, managers built, built scaled, scaled services, services Amazon, looking new, new teammate, teammate enthusiastic, able collaborate, collaborate effectively, effectively diverse, diverse team, team peers, Life Balance, Balance team, team puts, puts high, high value, value work, life balance, entire team, team co, located Boston, Boston Seaport, Seaport office, flexible people, people occasionally, occasionally need, need work, work home, generally core, office hours, Mentorship Career, Career Growth, Growth team, team dedicated, dedicated supporting, supporting new, new team, team members, team broad, broad mix, mix experience, experience levels, levels Amazon, Amazon tenures, building environment, environment celebrates, celebrates knowledge, knowledge sharing, sharing mentorship, senior members, members truly, truly enjoy, enjoy mentoring, sessions helping, helping career, career growth, Inclusive Team, Team Culture, Culture AWS, embrace differences, committed furthering, furthering culture, culture inclusion, led affinity, affinity groups, chapters globally, innovative benefit, benefit offerings, host annual, annual ongoing, ongoing learning, learning experiences, including Conversations, Conversations Race, Race Ethnicity, gender diversity, Amazon culture, culture inclusion, inclusion reinforced, Leadership Principles, remind team, team members, members seek, seek diverse, diverse perspectives, learn curious, earn trust, trust Amazon, Amazon committed, committed diverse, diverse inclusive, inclusive workforce, Amazon equal, equal opportunity, opportunity employer, employer discriminate, discriminate basis, basis race, gender identity, sexual orientation, protected veteran, veteran status, legally protected, protected status, individuals disabilities, disabilities like, like request, request accommodation, Amazon Dev, Dev Center, Center U.S., Inc. Job, Job ID, A1584516 job, job Description, Description AWS, AWS External, External Security, Security Services, redefining enterprises, enterprises defending, defending cloud, based applications, applications services, innovating cloud, cloud security, security services, services like, like Amazon, Amazon GuardDuty, Amazon Macie, Amazon Inspector, Amazon Detective, AWS Security, Security Hub, team growing, growing need, need experienced, experienced senior, senior product, p ...

# %%
#extract.keyterms.textrank(doc, topn=20)

# %%
#extract.keyterms.yake(doc, normalize="lemma", ngrams=2, topn=30)

# %%
results = [x for x in lnkjobs['nlp']]

for doc in results:
    print('-----------------------------------------------------------------')
    displacy.render(doc, style='ent', jupyter=True)
# Out:
# -----------------------------------------------------------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">About the job</br>Description</br></br>We’re seeking an experienced product leader to join us in our
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Boston
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  office to lead product management for
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AWS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ’s newest hybrid storage service.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AWS Outposts
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  provide fully managed AWS infrastructure and services to customers in their on-premises data centers.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amazon S3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  on
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Outposts
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , launched in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2020
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , provides hybrid object storage enabling customers to store and retrieve data on-premises using the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     S3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  programming model and features.</br></br>Our team is responsible for delivering this hybrid storage platform on
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Outposts
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . As part of the team, you will help shape object storage for the next generation hybrid computing platform.</br></br>Product Management at AWS is an opportunity to collaborate with engineering, design, and business development teams. We are looking for an entrepreneurial product leader who is passionate about delivering solutions to customers and excited about growing a new
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AWS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  business. Successful candidates will be able to build strategic roadmap for the business, dive into technical details working closely with the engineering team and drive the delivery of features that will delight our customers.</br></br>You will be joining an experienced team of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     engineers
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">JOB</span>
# </mark>
#  and product managers who have built and scaled services at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amazon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and beyond. We’re looking for a new teammate who is enthusiastic, empathetic, curious, motivated, reliable, and able to collaborate effectively with a diverse team of peers.</br></br>Work/Life Balance</br></br>Our team puts a high value on work-life balance. Our entire team is co-located in the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Boston Seaport
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  office, but we’re also flexible when people occasionally need to work from home. We generally keep core in-office hours from
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10am to 4pm
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# .</br></br>Mentorship and Career Growth</br></br>Our team is dedicated to supporting new team members. Our team has a broad mix of experience levels and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amazon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  tenures, and we’re building an environment that celebrates knowledge sharing and mentorship. Our senior members truly enjoy mentoring others through
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# -on-one sessions helping them with their career growth.</br></br>Inclusive Team Culture</br></br>Here at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AWS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , we embrace our differences. We are committed to furthering our culture of inclusion. We have
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ten
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  employee-led affinity groups, reaching
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     40,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </
# -----------------------------------------------------------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">About the job</br>Description</br></br>AWS External Security Services (ESS) is redefining how enterprises are defending their cloud-based applications and services. We are innovating in cloud security with services like
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amazon GuardDuty
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amazon Macie
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amazon Inspector
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amazon Detective
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AWS Security Hub
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . Our team is growing and we need an experienced senior product manager to help lead the product vision for
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amazon Detective
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of our most innovative security services focused on security investigation and response.</br></br>As principal product manager for
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amazon Detective
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  you will lead the product vision for a key set of features, such as expanded coverage, user experience, and cross service integration. As part of this, you will lead feature definition, prioritization, and partner coordination. We are looking for an experienced product leader who is passionate about solving customer problems and who has demonstrated success working backwards from ambiguous customer needs, translating them into disruptive, successful products that delight customers.</br></br>In this role, you will define, execute, and deliver a product roadmap for our customers. You will work closely with
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     dozens
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of internal
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AWS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  services and external partners to integrate their products with Detective. This role is inherently cross-functional -- you will work closely with engineering, design, partner, and executive teams to bring a consumer product to the market and develop and grow a new business opportunity for
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amazon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . A successful candidate will be highly analytical and organized, able to work effectively in a start-up like environment, and adept at synthesizing a variety of technologies and capabilities into high quality products and applications that customers love.</br></br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Working closely with teams
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  across
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AWS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , you’ll see and feel the impact of your work on our customers. This is a high visibility and high impact role that will interact with all levels of AWS leadership. Our ideal candidate is excited about the incredible opportunity cloud computing represents and is deeply passionate about delivering the highest quality services. You’re naturally customer-centric and thrive in a fast-paced environment that requires strong technical and business judgment and solid communication skills.</br></br></br></br>This position is located in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Boston
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  or
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Seattle
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# .</br></br>Here at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AWS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , we embrace our differences. We are committed to furthering our culture of inclusion. We have
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ten
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  employee-led affinity groups, reaching
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     40,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  employees in over
# <mark class="entity" style="background: #
# -----------------------------------------------------------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">About the job</br>About CyberArk:</br>CyberArk (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NASDAQ
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# : CYBR) is the global leader in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Identity Security
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Centered on privileged access management
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# , CyberArk provides the most comprehensive security offering for any identity – human or machine – across business applications, distributed workforces, hybrid cloud workloads and throughout the DevOps lifecycle. The world’s leading organizations trust CyberArk to help secure their most critical assets. To learn more about CyberArk, visit https://www.cyberark.com, read the CyberArk blogs or follow on
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Twitter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  via
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     @CyberArk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     LinkedIn
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  or
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Facebook
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .</div></span>
# -----------------------------------------------------------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">About the job</br>About
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     VERITAS
#
# Veritas
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  solves what no one else can. With an industry-leading product portfolio, we offer proven, modern, and integrated technology that brings together availability, protection, and insights. Our
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Veritas Enterprise Data Services Platform
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  addresses current and future data issues end-to-end – keeping mission-critical workloads highly available, protecting data everywhere, and providing insights to optimize costs and maintain regulatory readiness.</br></br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Veritas
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  supports
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     500
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# + data sources,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     150
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# + storage targets,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     50
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# + clouds, and any deployment model imaginable. We serve
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     99%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  of the Fortune 100,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     90%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  of the Fortune 500, and are the market leader in Software-defined
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Storage
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Data Protection
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , and Archiving.</br></br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Data Protection Group
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  drives the product strategy, roadmap, and engineering delivery of the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Veritas
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  products, which includes
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NetBackup
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     APTARE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Backup Exec
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , Enterprise Vault (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EV
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ), EV.cloud,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     eDiscovery
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  platform, and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Veritas SaaS Backup
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .</br></br>As a Product Manager in the NetBackup SaaS Protection and Backup Exec team, you will have the opportunity to join a team of highly experienced Product Managers working in a cross functional, diverse, global team who are at the leading edge of bringing next generation distributed multi cloud data protection software to market. In this role you will leverage and extend your business and technical acumen to assess, define and deliver strategy, capabilities and go to market for
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NetBackup SaaS Protection and Backup Exec
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .</br></br></br></br></br></br>At
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Veritas
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , we care about the causes close to your heart and enable you to volunteer, donate, and do good. We also value uniqueness and know that a more diverse and inclusive workforce makes a winning team, so come as you are! Interested? Then apply and find out more
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     about #TeamVTAS
#     <span style="font-size: 0.8em
# -----------------------------------------------------------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">About the job</br>Job Description:</br></br>Principal Product Manager, Cloud-Native Platform</br></br>The
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Global Platform
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  team at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DataRobot
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is responsible for building the architectural and foundational capabilities for easier services integration, deployment and operations of
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DataRobot AI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  platform in a heterogeneous infrastructure landscape. This includes almost everything we do around infrastructure (compute, storage, networking), private/public/hybrid cloud deployment experience, resource management, reliability, observability, security and administration.</br></br>As a senior member of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Platform Product Management
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  team at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DataRobot
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , you will lead the delivery of a high-performance, innovative, multi-cloud AI platform infrastructure roadmap, bringing together the latest advances in software (such as
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kubernetes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and the associated ecosystem) and cloud integrations across
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AWS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Azure
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     GCP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and more. You will influence the product vision and strategy around our cloud-based offerings (for SaaS and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     VPC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  customers), our journey towards a better cloud-native architecture and execute cross-functionally to address the myriad needs of internal engineering teams and external customers.</br></br>Core Responsibilities</br></br></br></br></br></br></br></br>All
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.S.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DataRobot
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  employees must be fully vaccinated against COVID-19. If there is a medical, religious, or other legally protected reason that prevents you from receiving an available
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     COVID-19 vaccination
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , and you are selected as a candidate for consideration, we have a process in place to evaluate requests for accommodation.</br></br>
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DataRobot
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  is proud to be an Equal Employment Opportunity and Affirmative Action employer. We do not discriminate based upon race, religion, color, national origin, gender (including pregnancy, childbirth, or related medical conditions), sexual orientation, gender identity, gender expression, age, status as a protected veteran, status as an individual with a disability, or other applicable legally protected characteristics.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DataRobot
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is committed to working with and providing reasonable accommodations to applicants with physical and mental disabilities. Please see
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the United States
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  Department of Labor’s
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EEO
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  poster and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EEO
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  poster supplement for additional information.</br></br>All applicant data submitted is handled in accordance with our Applicant Privacy Policy.</div></span>
# -----------------------------------------------------------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">About the job</br>Why will you enjoy this new opportunity?</br></br>VMware is the leader in virtualization and cloud infrastructure solutions that enables
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     more than 350,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  enterprise and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SMB
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  customers to thrive in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Cloud Era
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . We’re defining and delivering a world class customer experience for our SaaS and Subscription offerings.</br></br>As a within the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Product Management
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  team, you will be at the forefront of accelerating
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     VMware
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ’s SaaS Transformation and achieving
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     VMware
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ’s strategic priority to operate as a consumption-obsessed SaaS company.</br></br>This role is at a unique intersection of product management, business strategy and product operations, and would provide you a great platform for career growth into a product leadership role.</br></br></br></br></br></br></br></br></br></br>You will be reporting to Director,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Product Management
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , Subscription Models.</br></br></br></br>This role can be performed from anywhere in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the United States
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Canada
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , allowing you the flexibility to work from the location you feel most productive and comfortable.</br></br></br></br></br></br>Due to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Biden Administration
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  issuing
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     an Executive Order
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EO
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) that effectively mandates COVID-19 vaccination for all
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.S.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  based employees of federal contractors and subcontractors, all
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.S.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  based VMware employees will need to be fully vaccinated by
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     January 4th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2022
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , or by their
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  date of employment if after that date, subject to legally required accommodations.</br></br>Marketing</br></br>Product Management</br></br>Manager and Professional</br></br>Full Time</br></br>
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2021-11-05
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br></br>VMware Company Overview: At VMware, we believe that software has the power to unlock new opportunities for people and our planet. We look beyond the barriers of compromise to engineer new ways to make technologies work together seamlessly. Our cloud, mobility, and security software form a flexible, consistent digital foundation for securely delivering the apps, services and experiences that are transforming business innovation around the globe. At the core of what we do are our people who deeply value execution, passion, integrity, customers, and community. Shape what’s possible
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  at http://careers.vmware.com.</br></br>Equal Employment Opportunity Statement: VMware is an Equal Opportunity Employer a
# -----------------------------------------------------------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">About the job</br>Description</br></br>Are you passionate about
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Artificial Intelligence
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Machine Learning
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Deep Learning
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ? Are you eager to build out the platform as a service and scale the product for all Customer personas? Thrilled to be part of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amazon's AI organization
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  that has been pioneering and shaping the world’s AI technology? If you are someone who enjoys innovating, solving hard problems and working on the cutting edge of technology, come join ADS (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alexa Data Services
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) team! The ADS organization focuses on providing ground truth data to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alexa
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     engineers
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">JOB</span>
# </mark>
#  and scientists to build and improve ML models and continue evolve
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alexa
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  experience for
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amazon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  customers.</br></br>A day in the life</br></br>
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     This Principal Product Manager PMT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  will lead and drive cutting edge data science initiatives to automate and drive ML model improvements. You will be accountable for driving the entire product lifecycle, from platform product definition through specification, coding, quality assurance and launch to the world. Most importantly, you would take the lead in driving product innovations, partnering with stakeholders across
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Alexa Organization
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . This position involves regular communication with senior management on status, risks and change control. Cross-team coordination, project management and executive presentation skills are essential. You will have end to end ownership - all the way from defining the strategy to measuring metrics to monitoring
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     day
# ...
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , then this is your chance to be part of a challenging and strategic product team.</br></br>This role will report into the global product team that enables and supports
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amazon’s Product Assurance, Risk and Security
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (PARS) team. This team owns technology products that span all of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amazon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ’s consumer and retail business such as
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amazon.com
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amazon Private Brands
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amazon Go
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Whole Foods
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amazon Devices
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amazon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ’s
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     third
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  party fulfillment business, etc. You will have the opportunity to interact and work with emerging businesses at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amazon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  from inception through rapid growth. This team and role will provide a great opportunity to further build your career at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amazon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  as a product leader.</br></br>We’re looking for a strong technical Principal Product Manager to join our team in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Seattle
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     WA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . This role will be the product owner for the universal safety and compliance store to provide all downstream systems with a single source of truth for product compliance and safety decisions. This involves building interactive technology to serve the ever-changing regulatory landscape, machine learning driven products to identify hidden signals, and robust closed loop tools to protect our customers. The products are supported by established tech teams, and have a growing list of global stakeholders. You should have strong problem-solving skills, product management skills, excellent communication skills, and an understanding of how developers build, manage, and deploy their infrastructure and applications. You should also possess the ability to influence people across the organization from tech leadership to business managers. To do this, you must be able to manage complex initiatives across numerous business models, create certainty out of ambiguous requirements, while having a firm grasp over the operational, strategic, and technical aspects of the product.</br></br>You will work closely with various PARS teams globally. You will also work with various product tech teams and applied/data scientists within our org, as well as across
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amazon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (pr
# -----------------------------------------------------------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">About the job</br>The Product team at
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Klaviyo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  is continuously looking for ways to build and deliver the best product possible for our customers. We’re looking for a Senior Director of Product to join our rapidly growing team with expertise in solving problems with a customer-first mindset and bringing new products to market. You will develop a team of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Group Product Managers
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  as you work cross-functionally to guide product development from concept to launch.</br></br></br></br></br></br>At
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Klaviyo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  we value the unique backgrounds, experiences and perspectives each
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Klaviyo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  (we call ourselves
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Klaviyos
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ) brings to our workplace each and every day. We believe everyone deserves a fair shot at success and appreciate the experiences each person brings beyond the traditional job requirements. If you’re a close but not exact match with the description, we hope you’ll still consider applying.</br></br></br></br>Klaviyo is a world-leading marketing automation platform dedicated to accelerating revenue and customer connection for online businesses.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Klaviyo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  makes it easy to store, access, analyze and use transactional and behavioral data to power highly-targeted customer and prospect communications. The company's hybrid customer-data and marketing-platform model allows companies to grow by fostering direct relationships with customers, without giving up their valuable data to popular big-tech ad platforms.
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Over 265,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  innovative companies like
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Unilever
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , Custom Ink, Living Proof and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Huckberry
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  sell more with
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Klaviyo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . Learn more at .</div></span>
# -----------------------------------------------------------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">About the job</br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sophos
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is a worldwide leader in next-generation cybersecurity, protecting
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     more than 500,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  organizations and
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     millions
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of consumers in
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     more than 150
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  countries from
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ’s most advanced cyberthreats.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Powered by threat intelligence
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# , AI and machine learning from
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SophosLabs
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SophosAI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sophos
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  delivers a broad portfolio of advanced products and services to secure users, networks and endpoints against ransomware, malware, exploits, phishing and the wide range of other cyberattacks.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sophos
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  provides a single integrated cloud-based management console,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sophos Central
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  – the centerpiece of an adaptive cybersecurity ecosystem that features a centralized data lake that leverages a rich set of open APIs available to customers, partners, developers, and other cybersecurity vendors.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sophos
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  sells its products and services through reseller partners and managed service providers (MSPs) worldwide.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sophos
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  has major hubs around the globe. More information is available at www.sophos.com</div></span>

# %%
noun_chunks = extract.basics.noun_chunks(nlp(results[0]))
for n in noun_chunks:
    print(n)
# Out:
# job Description
# experienced product leader
# Boston
# MA office
# product management AWS
# newest hybrid storage service
# AWS Outposts
# fully managed AWS infrastructure services customers - premises data centers
# Amazon S3 Outposts
# _
# NUMBER
# _
# hybrid object storage
# customers
# store
# retrieve
# team
# hybrid storage platform Outposts
# team
# object storage generation hybrid computing platform
# Product Management AWS opportunity
# engineering
# design
# business development teams
# entrepreneurial product leader
# solutions customers
# new AWS business
# Successful candidates
# strategic roadmap business
# technical details
# closely engineering team drive delivery
# delight customers
# experienced team engineers product managers
# scaled services Amazon
# effectively diverse team peers
# Work / Life Balance team
# high value work - life balance
# flexible people
# work
# _
# NUMBER
# _
# NUMBER
# Mentorship Career Growth team
# new team members
# team broad mix experience levels
# Amazon tenures
# building environment
# knowledge
# sharing mentorship
# senior members
# mentoring - - sessions
# career growth
# Inclusive Team Culture AWS
# differences
# culture inclusion
# employee - led affinity groups
# _
# NUMBER
# _
# employees
# _
# NUMBER
# _
# chapters
# innovative benefit offerings
# host annual ongoing learning experiences
# Conversations Race Ethnicity
# ( CORE
# gender diversity
# Amazon culture inclusion
# _
# NUMBER
# _
# Leadership Principles
# team members
# diverse perspectives
# trust
# Amazon
# diverse inclusive workforce
# Amazon
# equal opportunity employer
# basis race
# ethnicity
# gender
# gender identity
# sexual orientation
# protected veteran status
# disability
# age
# , legally protected status
# individuals
# request accommodation
# _
# URL
# _
# U.S.
# Job ID

# %%
terms = extract.basics.terms(nlp(results[0]), ngs=3, ents=False, ncs=False, dedupe = False)
#print(len(list(terms)))
for n in terms:
    print(n)
# Out:
# job Description seeking
# Description seeking experienced
# seeking experienced product
# experienced product leader
# product leader join
# leader join Boston
# MA office lead
# office lead product
# lead product management
# product management AWS
# management AWS newest
# AWS newest hybrid
# newest hybrid storage
# hybrid storage service
# AWS Outposts provide
# Outposts provide fully
# provide fully managed
# fully managed AWS
# managed AWS infrastructure
# AWS infrastructure services
# infrastructure services customers
# premises data centers
# Amazon S3 Outposts
# provides hybrid object
# hybrid object storage
# object storage enabling
# storage enabling customers
# enabling customers store
# customers store retrieve
# store retrieve data
# premises S3 programming
# S3 programming model
# programming model features
# team responsible delivering
# responsible delivering hybrid
# delivering hybrid storage
# hybrid storage platform
# storage platform Outposts
# help shape object
# shape object storage
# object storage generation
# storage generation hybrid
# generation hybrid computing
# hybrid computing platform
# Product Management AWS
# Management AWS opportunity
# AWS opportunity collaborate
# opportunity collaborate engineering
# business development teams
# looking entrepreneurial product
# entrepreneurial product leader
# product leader passionate
# leader passionate delivering
# passionate delivering solutions
# delivering solutions customers
# solutions customers excited
# customers excited growing
# excited growing new
# growing new AWS
# new AWS business
# Successful candidates able
# candidates able build
# able build strategic
# build strategic roadmap
# strategic roadmap business
# dive technical details
# technical details working
# details working closely
# working closely engineering
# closely engineering team
# engineering team drive
# team drive delivery
# drive delivery features
# delivery features delight
# features delight customers
# joining experienced team
# experienced team engineers
# team engineers product
# engineers product managers
# product managers built
# managers built scaled
# built scaled services
# scaled services Amazon
# looking new teammate
# new teammate enthusiastic
# able collaborate effectively
# collaborate effectively diverse
# effectively diverse team
# diverse team peers
# Life Balance team
# Balance team puts
# team puts high
# puts high value
# high value work
# entire team co
# located Boston Seaport
# Boston Seaport office
# flexible people occasionally
# people occasionally need
# occasionally need work
# need work home
# Mentorship Career Growth
# Career Growth team
# Growth team dedicated
# team dedicated supporting
# dedicated supporting new
# supporting new team
# new team members
# team broad mix
# broad mix experience
# mix experience levels
# experience levels Amazon
# levels Amazon tenures
# building environment celebrates
# environment celebrates knowledge
# celebrates knowledge sharing
# knowledge sharing mentorship
# senior members truly
# members truly enjoy
# truly enjoy mentoring
# sessions helping career
# helping career growth
# Inclusive Team Culture
# Team Culture AWS
# committed furthering culture
# furthering culture inclusion
# led affinity groups
# innovative benefit offerings
# host annual ongoing
# annual ongoing learning
# ongoing learning experiences
# including Conversations Race
# Conversations Race Ethnicity
# Amazon culture inclusion
# culture inclusion reinforced
# remind team members
# team members seek
# members seek diverse
# seek diverse perspectives
# earn trust Amazon
# trust Amazon committed
# Amazon committed diverse
# committed diverse inclusive
# diverse inclusive workforce
# Amazon equal opportunity
# equal opportunity employer
# opportunity employer discriminate
# employer discriminate basis
# discriminate basis race
# protected veteran status
# legally protected status
# individuals disabilities like
# disabilities like request
# like request accommodation
# Amazon Dev Center
# Dev Center U.S.
# Inc. Job ID
# Boston
# MA
# AWS
# AWS Outposts
# Amazon S3 Outposts
# S3
# Outposts
# AWS
# Amazon
# Boston Seaport
# Amazon
# annual
# Amazon
# Amazon
# job Description
# experienced product leader
# Boston
# MA office
# product management AWS
# newest hybrid storage service
# AWS Outposts
# fully managed AWS infrastructure services customers - premises data centers
# Amazon S3 Outposts
# _
# NUMBER
# _
# hybrid object storage
# customers
# store
# retrieve
# team
# hybrid storage platform Outposts
# team
# object storage generation hybrid computing platform
# Product Management AWS opportunity
# engineering
# design
# business development teams
# entrepreneurial product leader
# solutions customers
# new AWS business
# Successful candidates
# strategic roadmap business
# technical details
# closely engineering team drive delivery
# delight customers
# experienced team engineers product managers
# scaled services Amazon
# effectively diverse team peers
# Work / Life Balance team
# high value work - life balance
# flexible people
# work
# _
# NUMBER
# _
# NUMBER
# Mentorship Career Growth team
# new team members
# team broad mix experience levels
# Amazon tenures
# building environment
# knowledge
# sharing mentorship
# senior members
# mentoring - - sessions
# career growth
# Inclusive Team Culture AWS
# differences
# culture inclusion
# employee - led affinity groups
# _
# NUMBER
# _
# employees
# _
# NUMBER
# _
# chapters
# innovative benefit offerings
# host annual ongoing learning experiences
# Conversations Race Ethnicity
# ( CORE
# gender diversity
# Amazon culture inclusion
# _
# NUMBER
# _
# Leadership Principles
# team members
# diverse perspectives
# trust
# Amazon
# diverse inclusive workforce
# Amazon
# equal opportunity employer
# basis race
# ethnicity
# gender
# gender identity
# sexual orientation
# protected veteran status
# disability
# age
# , legally protected status
# individuals
# request accommodation
# _
# URL
# _
# U.S.
# Job ID

# %%
terms = extract.basics.terms(nlp(results[0]), ngs=2, ents=True, ncs=True)
#print(len(list(terms)))
for n in terms:
    print(n)
# Out:
# job Description
# Description seeking
# seeking experienced
# experienced product
# product leader
# leader join
# join Boston
# MA office
# office lead
# lead product
# product management
# management AWS
# AWS newest
# newest hybrid
# hybrid storage
# storage service
# AWS Outposts
# Outposts provide
# provide fully
# fully managed
# managed AWS
# AWS infrastructure
# infrastructure services
# services customers
# premises data
# data centers
# Amazon S3
# S3 Outposts
# provides hybrid
# hybrid object
# object storage
# storage enabling
# enabling customers
# customers store
# store retrieve
# retrieve data
# premises S3
# S3 programming
# programming model
# model features
# team responsible
# responsible delivering
# delivering hybrid
# hybrid storage
# storage platform
# platform Outposts
# help shape
# shape object
# object storage
# storage generation
# generation hybrid
# hybrid computing
# computing platform
# Product Management
# Management AWS
# AWS opportunity
# opportunity collaborate
# collaborate engineering
# business development
# development teams
# looking entrepreneurial
# entrepreneurial product
# product leader
# leader passionate
# passionate delivering
# delivering solutions
# solutions customers
# customers excited
# excited growing
# growing new
# new AWS
# AWS business
# Successful candidates
# candidates able
# able build
# build strategic
# strategic roadmap
# roadmap business
# dive technical
# technical details
# details working
# working closely
# closely engineering
# engineering team
# team drive
# drive delivery
# delivery features
# features delight
# delight customers
# joining experienced
# experienced team
# team engineers
# engineers product
# product managers
# managers built
# built scaled
# scaled services
# services Amazon
# looking new
# new teammate
# teammate enthusiastic
# able collaborate
# collaborate effectively
# effectively diverse
# diverse team
# team peers
# Life Balance
# Balance team
# team puts
# puts high
# high value
# value work
# life balance
# entire team
# team co
# located Boston
# Boston Seaport
# Seaport office
# flexible people
# people occasionally
# occasionally need
# need work
# work home
# generally core
# office hours
# Mentorship Career
# Career Growth
# Growth team
# team dedicated
# dedicated supporting
# supporting new
# new team
# team members
# team broad
# broad mix
# mix experience
# experience levels
# levels Amazon
# Amazon tenures
# building environment
# environment celebrates
# celebrates knowledge
# knowledge sharing
# sharing mentorship
# senior members
# members truly
# truly enjoy
# enjoy mentoring
# sessions helping
# helping career
# career growth
# Inclusive Team
# Team Culture
# Culture AWS
# embrace differences
# committed furthering
# furthering culture
# culture inclusion
# led affinity
# affinity groups
# chapters globally
# innovative benefit
# benefit offerings
# host annual
# annual ongoing
# ongoing learning
# learning experiences
# including Conversations
# Conversations Race
# Race Ethnicity
# gender diversity
# Amazon culture
# culture inclusion
# inclusion reinforced
# Leadership Principles
# remind team
# team members
# members seek
# seek diverse
# diverse perspectives
# learn curious
# earn trust
# trust Amazon
# Amazon committed
# committed diverse
# diverse inclusive
# inclusive workforce
# Amazon equal
# equal opportunity
# opportunity employer
# employer discriminate
# discriminate basis
# basis race
# gender identity
# sexual orientation
# protected veteran
# veteran status
# legally protected
# protected status
# individuals disabilities
# disabilities like
# like request
# request accommodation
# Amazon Dev
# Dev Center
# Center U.S.
# Inc. Job
# Job ID
# Boston
# MA
# AWS
# Amazon S3 Outposts
# S3
# Outposts
# AWS
# Amazon
# Amazon
# annual
# Amazon
# Amazon
# experienced product leader
# product management AWS
# newest hybrid storage service
# fully managed AWS infrastructure services customers - premises data centers
# _
# NUMBER
# _
# hybrid object storage
# customers
# store
# retrieve
# team
# hybrid storage platform Outposts
# team
# object storage generation hybrid computing platform
# Product Management AWS opportunity
# engineering
# design
# business development teams
# entrepreneurial product leader
# new AWS business
# strategic roadmap business
# closely engineering team drive delivery
# experienced team engineers product managers
# scaled services Amazon
# effectively diverse team peers
# Work / Life Balance team
# high value work - life balance
# work
# _
# NUMBER
# _
# NUMBER
# Mentorship Career Growth team
# new team members
# team broad mix experience levels
# knowledge
# mentoring - - sessions
# Inclusive Team Culture AWS
# differences
# employee - led affinity groups
# _
# NUMBER
# _
# employees
# _
# NUMBER
# _
# chapters
# innovative benefit offerings
# host annual ongoing learning experiences
# Conversations Race Ethnicity
# ( CORE
# Amazon culture inclusion
# _
# NUMBER
# _
# trust
# diverse inclusive workforce
# equal opportunity employer
# ethnicity
# gender
# protected veteran status
# disability
# age
# , legally protected status
# individuals
# _
# URL
# _
# U.S.

# %% [raw]
# Interesting terms
# * Successful candidates
# * delight customers
# * help shape
# * collaborate engineering
# * looking entrepreneurial

# %%
lnkjobs.head()
# Out:
#    index                                            subject  \
# 0      0        Principal Product Manager - Technical - AWS
# 1      1  Principal Product Manager Technical, Amazon De...
# 2      2                           Sr. Data Product Manager
# 3      3  Senior Principal Product Manager (REMOTE ELIGI...
# 4      4   Principal Product Manager, Cloud-Native Platform
#
#                                                  url  \
# 0  https://www.linkedin.com/jobs/view/2600123751/...
# 1  https://www.linkedin.com/jobs/view/2798027544/...
# 2  https://www.linkedin.com/jobs/view/2787722444/...
# 3  https://www.linkedin.com/jobs/view/2799481430/...
# 4  https://www.linkedin.com/jobs/view/2802975863/...
#
#                                             job_desc  \
# 0  About the job\nDescription\n\nWe’re seeking an...
# 1  About the job\nDescription\n\nAWS External Sec...
# 2  About the job\nAbout CyberArk:\nCyberArk (NASD...
# 3  About the job\nAbout VERITAS\n\nVeritas solves...
# 4  About the job\nJob Description:\n\nPrincipal P...
#
#                                       clean_job_desc
# 0  job Description seeking experienced product le...
# 1  job Description AWS External Security Services...
# 2  job CyberArk : CyberArk ( NASDAQ : CYBR ) glob...
# 3  job VERITAS Veritas solves . industry - leadin...
# 4  job Job Description : Principal Product Manage...

# %%
jobs_dict = dict(zip(lnkjobs['url'], lnkjobs['nlp']))

# %%
temp_results = {
    'Terms': [],
    'Job_ID': []
}
for key, value in jobs_dict.items():
    chunks = list(extract.basics.terms(value, ngs=2, ents=False, ncs=False, dedupe = False))
    ID = re.search('\d{10}',key).group(0)
    for c in chunks:
        temp_results['Terms'].append(c.text)
        temp_results['Job_ID'].append(ID)

temp_results
# Out:
# {'Terms': ['job Description',
#   'Description seeking',
#   'seeking experienced',
#   'experienced product',
#   'product leader',
#   'leader join',
#   'join Boston',
#   'MA office',
#   'office lead',
#   'lead product',
#   'product management',
#   'management AWS',
#   'AWS newest',
#   'newest hybrid',
#   'hybrid storage',
#   'storage service',
#   'AWS Outposts',
#   'Outposts provide',
#   'provide fully',
#   'fully managed',
#   'managed AWS',
#   'AWS infrastructure',
#   'infrastructure services',
#   'services customers',
#   'premises data',
#   'data centers',
#   'Amazon S3',
#   'S3 Outposts',
#   'provides hybrid',
#   'hybrid object',
#   'object storage',
#   'storage enabling',
#   'enabling customers',
#   'customers store',
#   'store retrieve',
#   'retrieve data',
#   'premises S3',
#   'S3 programming',
#   'programming model',
#   'model features',
#   'team responsible',
#   'responsible delivering',
#   'delivering hybrid',
#   'hybrid storage',
#   'storage platform',
#   'platform Outposts',
#   'help shape',
#   'shape object',
#   'object storage',
#   'storage generation',
#   'generation hybrid',
#   'hybrid computing',
#   'computing platform',
#   'Product Management',
#   'Management AWS',
#   'AWS opportunity',
#   'opportunity collaborate',
#   'collaborate engineering',
#   'business development',
#   'development teams',
#   'looking entrepreneurial',
#   'entrepreneurial product',
#   'product leader',
#   'leader passionate',
#   'passionate delivering',
#   'delivering solutions',
#   'solutions customers',
#   'customers excited',
#   'excited growing',
#   'growing new',
#   'new AWS',
#   'AWS business',
#   'Successful candidates',
#   'candidates able',
#   'able build',
#   'build strategic',
#   'strategic roadmap',
#   'roadmap business',
#   'dive technical',
#   'technical details',
#   'details working',
#   'working closely',
#   'closely engineering',
#   'engineering team',
#   'team drive',
#   'drive delivery',
#   'delivery features',
#   'features delight',
#   'delight customers',
#   'joining experienced',
#   'experienced team',
#   'team engineers',
#   'engineers product',
#   'product managers',
#   'managers built',
#   'built scaled',
#   'scaled services',
#   'services Amazon',
#   'looking new',
#   'new teammate',
#   'teammate enthusiastic',
#   'able collaborate',
#   'collaborate effectively',
#   'effectively diverse',
#   'diverse team',
#   'team peers',
#   'Life Balance',
#   'Balance team',
#   'team puts',
#   'puts high',
#   'high value',
#   'value work',
#   'life balance',
#   'entire team',
#   'team co',
#   'located Boston',
#   'Boston Seaport',
#   'Seaport office',
#   'flexible people',
#   'people occasionally',
#   'occasionally need',
#   'need work',
#   'work home',
#   'generally core',
#   'office hours',
#   'Mentorship Career',
#   'Career Growth',
#   'Growth team',
#   'team dedicated',
#   'dedicated supporting',
#   'supporting new',
#   'new team',
#   'team members',
#   'team broad',
#   'broad mix',
#   'mix experience',
#   'experience levels',
#   'levels Amazon',
#   'Amazon tenures',
#   'building environment',
#   'environment celebrates',
#   'celebrates knowledge',
#   'knowledge sharing',
#   'sharing mentorship',
#   'senior members',
#   'members truly',
#   'truly enjoy',
#   'enjoy mentoring',
#   'sessions helping',
#   'helping career',
#   'career growth',
#   'Inclusive Team',
#   'Team Culture',
#   'Culture AWS',
#   'embrace differences',
#   'committed furthering',
#   'furthering culture',
#   'culture inclusion',
#   'led affinity',
#   'affinity groups',
#   'chapters globally',
#   'innovative benefit',
#   'benefit offerings',
#   'host annual',
#   'annual ongoing',
#   'ongoing learning',
#   'learning experiences',
#   'including Conversations',
#   'Conversations Race',
#   'Race Ethnicity',
#   'gender diversity',
#   'Amazon culture',
#   'culture inclusion',
#   'inclusion reinforced',
#   'Leadership Principles',
#   'remind team',
#   'team members',
#   'members seek',
#   'seek diverse',
#   'diverse perspectives',
#   'learn curious',
#   'earn trust',
#   'trust Amazon',
#   'Amazon committed',
#   'committed diverse',
#   'diverse inclusive',
#   'inclusive workforce',
#   'Amazon equal',
#   'equal opportunity',
#   'opportunity employer',
#   'employer discriminate',
#   'discriminate basis',
#   'basis race',
#   'gender identity',
#   'sexual orientation',
#   'protected veteran',
#   'veteran status',
#   'legally protected',
#   'protected status',
#   'individuals disabilities',
#   'disabilities like',
#   'like request',
#   'request accommodation',
#   'Amazon Dev',
#   'Dev Center',
#   'Center U.S.',
#   'Inc. Job',
#   'Job ID',
#   'Boston',
#   'MA',
#   'AWS',
#   'AWS Outposts',
#   'Amazon S3 Outposts',
#   'S3',
#   'Outposts',
#   'AWS',
#   'Amazon',
#   'Boston Seaport',
#   'Amazon',
#   'annual',
#   'Amazon',
#   'Amazon',
#   'job Description',
#   'experienced product leader',
#   'Boston',
#   'MA office',
#   'product management AWS',
#   'newest hybrid storage service',
#   'AWS Outposts',
#   'fully managed AWS infrastructure services customers - premises data centers',
#   'Amazon S3 Outposts',
#   '_',
#   'NUMBER',
#   '_',
#   'hybrid object storage',
#   'customers',
#   'store',
#   'retrieve',
#   'team',
#   'hybrid storage platform Outposts',
#   'team',
#   'object storage generation hybrid computing platform',
#   'Product Management AWS opportunity',
#   'engineering',
#   'design',
#   'business development teams',
#   'entrepreneurial product leader',
#   'solutions customers',
#   'new AWS business',
#   'Successful candidates',
#   'strategic roadmap business',
#   'technical details',
#   'closely engineering team drive delivery',
#   'delight customers',
#   'experienced team engineers product managers',
#   'scaled services Amazon',
#   'effectively diverse team peers',
#   'Work / Life Balance team',
#   'high value work - life balance',
#   'flexible people',
#   'work',
#   '_',
#   'NUMBER',
#   '_',
#   'NUMBER',
#   'Mentorship Career Growth team',
#   'new team members',
#   'team broad mix experience levels',
#   'Amazon tenures',
#   'building environment',
#   'knowledge',
#   'sharing mentorship',
#   'senior members',
#   'mentoring - - sessions',
#   'career growth',
#   'Inclusive Team Culture AWS',
#   'differences',
#   'culture inclusion',
#   'employee - led affinity groups',
#   '_',
#   'NUMBER',
#   '_',
#   'employees',
#   '_',
#   'NUMBER',
#   '_',
#   'chapters',
#   'innovative benefit offerings',
#   'host annual ongoing learning experiences',
#   'Conversations Race Ethnicity',
#   '( CORE',
#   'gender diversity',
#   'Amazon culture inclusion',
#   '_',
#   'NUMBER',
#   '_',
#   'Leadership Principles',
#   'team members',
#   'diverse perspectives',
#   'trust',
#   'Amazon',
#   'diverse inclusive workforce',
#   'Amazon',
#   'equal opportunity employer',
#   'basis race',
#   'ethnicity',
#   'gender',
#   'gender identity',
#   'sexual orientation',
#   'protected veteran status',
#   'disability',
#   'age',
#   ', legally protected status',
#   'individuals',
#   'request accommodation',
#   '_',
#   'URL',
#   '_',
#   'U.S.',
#   'Job ID',
#   'job Description',
#   'Description AWS',
#   'AWS External',
#   'External Security',
#   'Security Services',
#   'redefining enterprises',
#   'enterprises defending',
#   'defending cloud',
#   'based applications',
#   'applications services',
#   'innovating cloud',
#   'cloud security',
#   'security services',
#   'services like',
#   'like Amazon',
#   'Amazon GuardDuty',
#   'Amazon Macie',
#   'Amazon Inspector',
#   'Amazon Detective',
#   'AWS Security',
#   'Security Hub',
#   'team growing',
#   'growing need',
#   'need experienced',
#   'experienced senior',
#   'senior product',
#   'product manager',
#   'manager help',
#   'help lead',
#   'lead product',
#   'product vision',
#   'vision Amazon',
#   'Amazon Detective',
#   'innovative security',
#   'security services',
#   'services focused',
#   'focused security',
#   'security investigation',
#   'investigation response',
#   'principal product',
#   'product manager',
#   'manager Amazon',
#   'Amazon Detective',
#   'Detective lead',
#   'lead product',
#   'product vision',
#   'vision key',
#   'key set',
#   'set features',
#   'expanded coverage',
#   'user experience',
#   'cross service',
#   'service integration',
#   'lead feature',
#   'feature definition',
#   'partner coordination',
#   'looking experienced',
#   'experienced product',
#   'product leader',
#   'leader passionate',
#   'passionate solving',
#   'solving customer',
#   'customer problems',
#   'problems demonstrated',
#   'demonstrated success',
#   'success working',
#   'working backwards',
#   'backwards ambiguous',
#   'ambiguous customer',
#   'customer needs',
#   'translating disruptive',
#   'successful products',
#   'products delight',
#   'delight customers',
#   'deliver product',
#   'product roadmap',
#   'roadmap customers',
#   'work closely',
#   'closely dozens',
#   'dozens internal',
#   'internal AWS',
#   'AWS services',
#   'services external',
#   'external partners',
#   'partners integrate',
#   'integrate products',
#   'products Detective',
#   'role inherently',
#   'inherently cross',
#   'work closely',
#   'closely engineering',
#   'executive teams',
#   'teams bring',
#   'bring consumer',
#   'consumer product',
#   'product market',
#   'market develop',
#   'develop grow',
#   'grow new',
#   'new business',
#   'business opportunity',
#   'opportunity Amazon',
#   'successful candidate',
#   'candidate highly',
#   'highly analytical',
#   'analytical organized',
#   'able work',
#   'work effectively',
#   'effectively start',
#   'like environment',
#   'adept synthesizing',
#   'synthesizing variety',
#   'variety technologies',
#   'technologies capabilities',
#   'capabilities high',
#   'high quality',
#   'quality products',
#   'products applications',
#   'applications customers',
#   'customers love',
#   'Working closely',
#   'closely teams',
#   'teams AWS',
#   'feel impact',
#   'impact work',
#   'work customers',
#   'high visibility',
#   'visibility high',
#   'high impact',
#   'impact role',
#   'role interact',
#   'interact levels',
#   'levels AWS',
#   'AWS leadership',
#   'ideal candidate',
#   'candidate excited',
#   'excited incredible',
#   'incredible opportunity',
#   'opportunity cloud',
#   'cloud computing',
#   'computing represents',
#   'represents deeply',
#   'deeply passionate',
#   'passionate delivering',
#   'delivering highest',
#   'highest quality',
#   'quality services',
#   'naturally customer',
#   'centric thrive',
#   'thrive fast',
#   'paced environment',
#   'environment requires',
#   'requires strong',
#   'strong technical',
#   'technical business',
#   'business judgment',
#   'judgment solid',
#   'solid communication',
#   'communication skills',
#   'position located',
#   'located Boston',
#   'Boston Seattle',
#   'embrace differences',
#   'committed furthering',
#   'furthering culture',
#   'culture inclusion',
#   'led affinity',
#   'affinity groups',
#   'chapters globally',
#   'innovative benefit',
#   'benefit offerings',
#   'host annual',
#   'annual ongoing',
#   'ongoing learning',
#   'learning experiences',
#   'including Conversations',
#   'Conversations Race',
#   'Race Ethnicity',
#   'gender diversity',
#   'Amazon culture',
#   'culture inclusion',
#   'inclusion reinforced',
#   'Leadership Principles',
#   'remind team',
#   'team members',
#   'members seek',
#   'seek diverse',
#   'diverse perspectives',
#   'learn curious',
#   'earn trust',
#   'Career Growth',
#   'Growth team',
#   'team dedicated',
#   'dedicated supporting',
#   'supporting new',
#   'new members',
#   'broad mix',
#   'mix experience',
#   'experience levels',
#   'levels tenures',
#   'building environment',
#   'environment celebrates',
#   'celebrates knowledge',
#   'knowledge sharing',
#   'sharing mentorship',
#   'senior members',
#   'members enjoy',
#   'mentoring thorough',
#   'code reviews',
#   'care career',
#   'career growth',
#   'growth strive',
#   'strive assign',
#   'assign projects',
#   'projects based',
#   'based help',
#   'help team',
#   'team member',
#   'member develop',
#   'develop better',
#   'rounded engineer',
#   'engineer enable',
#   'enable complex',
#   'complex tasks',
#   'tasks future',
#   'team puts',
#   'puts high',
#   'high value',
#   'value work',
#   'live balance',
#   'hours spend',
#   'spend home',
#   'home work',
#   'flow establish',
#   'establish brings',
#   'brings energy',
#   'energy parts',
#   'parts life',
#   'believe striking',
#   'striking right',
#   'right balance',
#   'balance personal',
#   'personal professional',
#   'professional life',
#   'life critical',
#   'critical life',
#   'long happiness',
#   'happiness fulfillment',
#   'offer flexibility',
#   'flexibility working',
#   'working hours',
#   'hours encourage',
#   'encourage find',
#   'find balance',
#   'balance work',
#   'work personal',
#   'personal lives',
#   'team dedicated',
#   'dedicated supporting',
#   'supporting new',
#   'new members',
#   'broad mix',
#   'mix experience',
#   'experience levels',
#   'levels tenures',
#   'building environment',
#   'environment celebrates',
#   'celebrates knowledge',
#   'knowledge sharing',
#   'sharing mentorship',
#   'Amazon committed',
#   'committed diverse',
#   'diverse inclusive',
#   'inclusive workplace',
#   'Amazon equal',
#   'equal opportunity',
#   'opportunity employer',
#   'employer discriminate',
#   'discriminate basis',
#   'basis race',
#   'national origin',
#   'gender identity',
#   'sexual orientation',
#   'protected veteran',
#   'veteran status',
#   'legally protected',
#   'protected status',
#   'individuals disabilities',
#   'disabilities like',
#   'like request',
#   'request accommodation',
#   'Amazon Dev',
#   'Dev Center',
#   'Center U.S.',
#   'Inc. Job',
#   'Job ID',
#   'Amazon GuardDuty',
#   'Amazon Macie',
#   'Amazon Inspector',
#   'Amazon Detective',
#   'AWS Security Hub',
#   'Amazon Detective',
#   'Amazon Detective',
#   'dozens',
#   'AWS',
#   'Amazon',
#   'AWS',
#   'Boston',
#   'Seattle',
#   'AWS',
#   'annual',
#   'Mentorship & Career',
#   'hours',
#   'working hours',
#   'Amazon',
#   'Amazon',
#   'job',
#   'Description AWS External Security Services',
#   '( ESS',
#   'enterprises',
#   'cloud - based applications services',
#   'cloud security services',
#   'Amazon GuardDuty',
#   'AWS Security Hub',
#   'team',
#   'need',
#   'product vision',
#   'Amazon Detective',
#   'innovative security services',
#   'security investigation response',
#   'principal product manager',
#   'Amazon Detective',
#   'product vision key set features',
#   'expanded coverage',
#   'user experience',
#   'cross',
#   'service integration',
#   ', lead feature definition',
#   'prioritization',
#   'partner coordination',
#   'looking experienced product leader passionate solving customer problems',
#   'success',
#   'ambiguous customer needs',
#   'disruptive , successful products delight customers',
#   'role',
#   'product roadmap customers',
#   'dozens',
#   'internal AWS services external partners',
#   'products',
#   'role',
#   'executive teams',
#   'consumer product market',
#   'new business opportunity',
#   'Amazon',
#   'successful candidate highly analytical organized , able work effectively start - like environment',
#   'variety technologies',
#   'high quality products applications customers',
#   'teams AWS',
#   'impact work customers',
#   'high visibility high impact role',
#   'levels AWS leadership',
#   'ideal candidate',
#   'incredible opportunity cloud computing',
#   'highest quality services',
#   'customer - centric',
#   'fast - paced environment',
#   'strong technical business judgment solid communication skills',
#   'position',
#   'Boston Seattle',
#   'differences',
#   'culture inclusion',
#   'employee - led affinity groups',
#   '_',
#   'NUMBER',
#   '_',
#   'employees',
#   '_',
#   'NUMBER',
#   '_',
#   'chapters',
#   'innovative benefit offerings',
#   'host annual ongoing learning experiences',
#   'Conversations Race Ethnicity',
#   '( CORE',
#   'gender diversity',
#   'Amazon culture inclusion',
#   '_',
#   'NUMBER',
#   '_',
#   'Leadership Principles',
#   'team members',
#   'diverse perspectives',
#   'trust',
#   'Mentorship & Career Growth team',
#   'new members',
#   'broad mix experience levels tenures',
#   'building environment',
#   'knowledge',
#   'sharing mentorship',
#   'senior members',
#   'thorough , kind , code reviews',
#   'care career growth',
#   'projects',
#   'help team member',
#   'better - rounded engineer',
#   'complex tasks',
#   'team',
#   'high value work - live balance',
#   'hours',
#   'home work',
#   'flow establish',
#   'energy parts life',
#   'right balance personal professional life critical life - long happiness fulfillment',
#   'flexibility',
#   'working hours',
#   'balance work personal lives',
#   'team',
#   'new members',
#   'broad mix experience levels tenures',
#   'building environment',
#   'knowledge',
#   'sharing mentorship',
#   'Amazon',
#   'diverse inclusive workplace',
#   'Amazon equal opportunity employer',
#   'basis race',
#   'national origin',
#   'gender',
#   'gender identity',
#   'sexual orientation',
#   'protected veteran status',
#   'disability',
#   'age',
#   ', legally protected status',
#   'individuals',
#   'request accommodation',
#   '_',
#   'URL',
#   '_',
#   'ExternalSecurityServices - Amazon Dev Center',
#   'Job ID',
#   'job CyberArk',
#   'global leader',
#   'leader Identity',
#   'Identity Security',
#   'Centered privileged',
#   'privileged access',
#   'access management',
#   'CyberArk provides',
#   'provides comprehensive',
#   'comprehensive security',
#   'security offering',
#   'offering identity',
#   'human machine',
#   'business applications',
#   'distributed workforces',
#   'hybrid cloud',
#   'cloud workloads',
#   'workloads DevOps',
#   'DevOps lifecycle',
#   'world leading',
#   'leading organizations',
#   'organizations trust',
#   'trust CyberArk',
#   'CyberArk help',
#   'help secure',
#   'secure critical',
#   'critical assets',
#   'learn CyberArk',
#   'read CyberArk',
#   'CyberArk blogs',
#   'blogs follow',
#   'follow Twitter',
#   'Twitter @CyberArk',
#   'LinkedIn Facebook',
#   'Identity Security',
#   'Twitter @CyberArk',
#   'LinkedIn Facebook',
#   'job',
#   'CyberArk',
#   'CyberArk',
#   'NASDAQ',
#   ': CYBR',
#   'global leader Identity Security',
#   'Centered privileged access management',
#   'CyberArk',
#   'comprehensive security offering identity',
#   'human machine',
#   'business applications',
#   'workforces',
#   'hybrid cloud',
#   'DevOps lifecycle',
#   'CyberArk',
#   'critical assets',
#   'CyberArk',
#   '_',
#   'URL',
#   '_',
#   'CyberArk blogs',
#   'Twitter @CyberArk',
#   'LinkedIn Facebook',
#   'job VERITAS',
#   'VERITAS Veritas',
#   'Veritas solves',
#   'leading product',
#   'product portfolio',
#   'offer proven',
#   'integrated technology',
#   'technology brings',
#   'brings availability',
#   'Veritas Enterprise',
#   'Enterprise Data',
#   'Data Services',
#   'Services Platform',
#   'Platform addresses',
#   'addresses current',
#   'current future',
#   'future data',
#   'data issues',
#   'issues end',
#   'keeping mission',
#   'critical workloads',
#   'workloads highly',
#   'highly available',
#   'protecting data',
#   'providing insights',
#   'insights optimize',
#   'optimize costs',
#   'costs maintain',
#   'maintain regulatory',
#   'regulatory readiness',
#   'Veritas supports',
#   '+ data',
#   'data sources',
#   '+ storage',
#   'storage targets',
#   '+ clouds',
#   'deployment model',
#   'model imaginable',
#   'market leader',
#   'leader Software',
#   'defined Storage',
#   'Data Protection',
#   'Data Protection',
#   'Protection Group',
#   'Group drives',
#   'drives product',
#   'product strategy',
#   'engineering delivery',
#   'delivery Veritas',
#   'Veritas products',
#   'includes NetBackup',
#   'Backup Exec',
#   'Enterprise Vault',
#   'eDiscovery platform',
#   'Veritas SaaS',
#   'SaaS Backup',
#   'Product Manager',
#   'Manager NetBackup',
#   'NetBackup SaaS',
#   'SaaS Protection',
#   'Protection Backup',
#   'Backup Exec',
#   'Exec team',
#   'opportunity join',
#   'join team',
#   'team highly',
#   'highly experienced',
#   'experienced Product',
#   'Product Managers',
#   'Managers working',
#   'working cross',
#   'cross functional',
#   'global team',
#   'team leading',
#   'leading edge',
#   'edge bringing',
#   'bringing generation',
#   'generation distributed',
#   'distributed multi',
#   'multi cloud',
#   'cloud data',
#   'data protection',
#   'protection software',
#   'software market',
#   'role leverage',
#   'leverage extend',
#   'extend business',
#   'business technical',
#   'technical acumen',
#   'acumen assess',
#   'define deliver',
#   'deliver strategy',
#   'capabilities market',
#   'market NetBackup',
#   'NetBackup SaaS',
#   'SaaS Protection',
#   'Protection Backup',
#   'Backup Exec',
#   'care causes',
#   'causes close',
#   'close heart',
#   'heart enable',
#   'enable volunteer',
#   'value uniqueness',
#   'uniqueness know',
#   'know diverse',
#   'diverse inclusive',
#   'inclusive workforce',
#   'workforce makes',
#   'makes winning',
#   'winning team',
#   'apply find',
#   'VERITAS Veritas',
#   'Veritas Enterprise Data Services Platform',
#   'Veritas',
#   'Data Protection Group',
#   'Veritas',
#   'NetBackup',
#   'APTARE',
#   'Backup Exec',
#   'Enterprise Vault',
#   'eDiscovery',
#   'Veritas SaaS Backup',
#   'NetBackup',
#   'Veritas',
#   'job',
#   'VERITAS Veritas',
#   'industry - leading product portfolio',
#   'proven , modern , integrated technology',
#   'availability',
#   'protection',
#   'insights',
#   'Veritas Enterprise Data Services Platform',
#   'current future data issues',
#   'end - - end',
#   'mission - critical workloads',
#   'data',
#   'insights',
#   'costs',
#   'regulatory readiness',
#   'Veritas',
#   '_',
#   'NUMBER',
#   '_',
#   'data sources',
#   '_',
#   'NUMBER',
#   '_',
#   'storage targets',
#   '_',
#   'NUMBER',
#   '_',
#   'clouds',
#   ', deployment model imaginable',
#   '_',
#   'NUMBER',
#   '_',
#   '%',
#   'Fortune _',
#   'NUMBER',
#   '_',
#   '_',
#   'NUMBER',
#   '_',
#   '%',
#   'Fortune _',
#   'NUMBER',
#   '_',
#   'market leader Software - defined Storage',
#   'Data Protection',
#   'Archiving',
#   'Data Protection Group',
#   'product strategy',
#   'roadmap',
#   'engineering delivery Veritas products',
#   'NetBackup',
#   'APTARE',
#   'Backup Exec',
#   'Enterprise Vault',
#   ...],
#  'Job_ID': ['2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2600123751',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2798027544',
#   '2787722444',
#   '2787722444',
#   '2787722444',
#   '2787722444',
#   '2787722444',
#   '2787722444',
#   '2787722444',
#   '2787722444',
#   '2787722444',
#   '2787722444',
#   '2787722444',
#   '2787722444',
#   '2787722444',
#   '2787722444',
#   '2787722444',
#   '2787722444',
#   '2787722444',
#   '2787722444',
#   '2787722444',
#   '2787722444',
#   '2787722444',
#   '2787722444',
#   '2787722444',
#   '2787722444',
#   '2787722444',
#   '2787722444',
#   '2787722444',
#   '2787722444',
#   '2787722444',
#   '2787722444',
#   '2787722444',
#   '2787722444',
#   '2787722444',
#   '2787722444',
#   '2787722444',
#   '2787722444',
#   '2787722444',
#   '2787722444',
#   '2787722444',
#   '2787722444',
#   '2787722444',
#   '2787722444',
#   '2787722444',
#   '2787722444',
#   '2787722444',
#   '2787722444',
#   '2787722444',
#   '2787722444',
#   '2787722444',
#   '2787722444',
#   '2787722444',
#   '2787722444',
#   '2787722444',
#   '2787722444',
#   '2787722444',
#   '2787722444',
#   '2787722444',
#   '2787722444',
#   '2787722444',
#   '2787722444',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   '2799481430',
#   ...]}

# %%
terms = pd.DataFrame(temp_results)
terms.head()
# Out:
#                  Terms      Job_ID
# 0      job Description  2600123751
# 1  Description seeking  2600123751
# 2  seeking experienced  2600123751
# 3  experienced product  2600123751
# 4       product leader  2600123751

# %%
grouped = terms.groupby('Terms').count().reset_index()
grouped.sort_values('Job_ID', ascending=False).head(50)
# Out:
#                          Terms  Job_ID
# 534                          _      77
# 348                     NUMBER      40
# 69                      Amazon      34
# 2371        sexual orientation      20
# 1859           national origin      17
# 1403           gender identity      15
# 2650            veteran status      13
# 672                 basis race      12
# 416            Product Manager      11
# 959                  customers      11
# 2227     request accommodation      10
# 582                        age      10
# 359                    Nutanix       9
# 2511                      team       9
# 156                   Coinbase       9
# 463                     Sophos       9
# 944          culture inclusion       9
# 1398                    gender       9
# 1179                 employees       8
# 1602                       job       8
# 725       building environment       8
# 2377        sharing mentorship       8
# 283                     Job ID       8
# 74            Amazon Detective       8
# 194                  DataRobot       7
# 1607           job Description       7
# 1092                disability       7
# 413         Product Management       7
# 1695         legally protected       7
# 2537              team members       7
# 2281                      role       7
# 492                        URL       7
# 2133         protected veteran       7
# 1931      opportunity employer       6
# 1265         equal opportunity       6
# 2345            senior members       6
# 60                       Alexa       6
# 1508           ideal candidate       6
# 1114      diverse perspectives       6
# 64          Alexa Organization       6
# 2685                      work       6
# 1097        discriminate basis       6
# 1111         diverse inclusive       6
# 1545  individuals disabilities       6
# 1544               individuals       6
# 1399          gender diversity       6
# 319                  ML models       6
# 2718             working hours       6
# 308      Leadership Principles       6
# 38                         AWS       6

# %%
grouped[grouped['Terms'].str.contains('roadmap', na=False)]
# Out:
#                                                   Terms  Job_ID
# 1558                             infrastructure roadmap       1
# 1661  lead delivery high - performance , innovative ...       1
# 2088                                    product roadmap       2
# 2089                          product roadmap customers       1
# 2090    product roadmap meet requirements business plan       1
# 2091                                   product roadmaps       2
# 2274                                            roadmap       1
# 2275                                   roadmap business       1
# 2276                                  roadmap customers       1
# 2277                                       roadmap meet       1
# 2444                                  strategic roadmap       1
# 2445                         strategic roadmap business       1

# %%
rm1 = nlp("product roadmap")
rm2 = nlp("infrastructure roadmap")
rm3 = nlp("roadmap business")
rm4 = nlp("customer")
rm5 = nlp("product roadmaps")

rm1.similarity(rm5)
# Out:
# 0.8902945854485927

# %%
str_terms = [] # string is used to filter out dedups
span_terms = []
for key, value in jobs_dict.items():
    chunks = list(extract.basics.terms(value, ngs=2, ents=False, ncs=True, dedupe = True))
    ID = re.search('\d{10}',key).group(0)
    for c in chunks:
        if(len(c.text) > 6):
            if c.text not in str_terms:
                span_terms.append(c)
                str_terms.append(c.text)

# %%
def find_similar_terms(span):
    
    ceil = 1.0
    a = 0.85
    b = 0.72
    c = 0.69
    
    key_a = str(a) + "_" + str(ceil)
    key_b = str(b) + "_" + str(a-0.01)
    key_c = str(c) + "_" + str(b-0.01)
    results = {
        'key_term': span,
        key_a: [],
        key_b: [],
        key_c: []
    }
    
    for t in span_terms:
        score = span.similarity(t)
        if(score >= a and score < ceil):
            results[key_a].append((t, score))
        elif(score >= b and score < a):
            results[key_b].append((t, score))
        elif(score >= c and score < b):
            results[key_c].append((t, score))
    
    return results

# %%
terms_clusters = {}
for term in span_terms:
    terms_clusters[term.text] = find_similar_terms(term)
# Out:
# /var/folders/7g/_mtrfg1d7qd9x9npv4fwkd9c0000gn/T/ipykernel_47938/1589351058.py:19: UserWarning: [W008] Evaluating Span.similarity based on empty vectors.
#   score = span.similarity(t)

# %%
#persons_vc_map  = {ent.text:ent.vector  for ent in doc.ents if ent.label_=='PERSON' } 
terms2 = {chunk.text:chunk.vector for chunk in span_terms}
# Out:
#         0                                                  1
# 0   Terms  0               job Description
# 1           De...
# 1  Job_ID  0       2600123751
# 1       2600123751
# 2       ...

# %%
df = pd.DataFrame([(key , val ) for key , val in terms2.items()])
X = np.array([a for a in df[1]])
kmeans_terms = KMeans(n_clusters=50).fit(X)
df ['labels'] =  kmeans_terms.labels_
df
# Out:
#                                                       0  \
# 0                                       job Description
# 1                                   Description seeking
# 2                                   seeking experienced
# 3                                   experienced product
# 4                                        product leader
# ...                                                 ...
# 2639  Sophos Central – centerpiece adaptive cybersec...
# 2640                              centralized data lake
# 2641                                           partners
# 2642                            Sophos major hubs globe
# 2643                                        information
#
#                                                       1  labels
# 0     [-0.21057501, 0.0414495, -0.420905, -0.045852,...      24
# 1     [0.061595, -0.1956505, -0.41362998, 0.08548801...       6
# 2     [0.1363455, -0.138585, -0.179095, 0.051354505,...      20
# 3     [-0.22814949, 0.251275, -0.0824755, -0.1180255...       8
# 4     [-0.33899498, 0.452585, 0.0947745, 0.128925, 0...       8
# ...                                                 ...     ...
# 2639  [-0.107221425, 0.08308, 0.124375716, -0.101335...      19
# 2640  [-0.14853166, -0.09586332, 0.13034667, 0.00875...      39
# 2641  [-0.25558, -0.39295, 0.0096051, -0.38615, 0.30...       1
# 2642  [0.24185124, -0.1791905, 0.059178747, -0.10275...      23
# 2643  [-0.16667, 0.24299, -0.39939, 0.20986, 0.14948...       6
#
# [2644 rows x 3 columns]

# %%
for label, names in df.groupby('labels'):
    print("cluster {} , values : {}".format( label, names[0].tolist()))
    print("++++++++++++++++")
# Out:
# cluster 0 , values : ['help shape', 'flexible people', 'people occasionally', 'occasionally need', 'effectively start', 'based help', 'find balance', 'thorough , kind , code reviews', 'help secure', 'apply find', 'reason prevents', 'process place', 'productive comfortable', 'need fully', 'look barriers', 'Shape possible', 'possible today', 'hard problems', 'way defining', 'things look', 'default trust', 'way relevant', 'view Pay', 'need reasonable', 'let know', 'quick access', 'screen reading', 'free step', 'step step', 'step tutorial', 'tutorial found', 'regulate way', 'agreeing use', 'quick access screen', 'free step step tutorial', 'kind direct', 'makes easy', 'access clean', 'Like parent', 'mission clean', 'looks push', 'push envelope', 'process imagine', 'Want fast', 'rewrite way', 'changing treat', 'clothes wear', 'makeup everyday', 'everyday objects', 'pressing problems', 'ways problem', 'advised safe', 'clothes', 'drivers safer', 'things makes', 'safe welcoming', 'help realize', 'DESCRIPTION Want', 'need quickly', 'makes possible', 'stores seconds', 'makes query', 'effective way', 'way exceptionally', 'exceptionally easy', 'easy use', 'need exhibit', 'owners comfortable', 'comfortable sharing', 'performant cost effective way exceptionally easy use', 'deep details ideas', 'hard carry', 'need exceptionally', 'like help', 'find buy', 'continuously looking', 'looking ways', 'close exact', 'exact match', 'consider applying', 'easy store', 'set open']
# ++++++++++++++++
# cluster 1 , values : ['responsible delivering', 'Mentorship Career', 'Career Growth', 'dedicated supporting', 'sharing mentorship', 'sessions helping', 'helping career', 'career growth', 'committed furthering', 'Leadership Principles', 'committed diverse', 'diverse inclusive', 'inclusive workforce', 'effectively diverse team peers', 'employee - led affinity groups', 'host annual ongoing learning experiences', 'diverse inclusive workforce', 'partner coordination', 'demonstrated success', 'growth strive', 'member develop', 'inclusive workplace', 'Mentorship & Career', 'success', 'care career growth', 'diverse inclusive workplace', 'organizations trust', 'keeping mission', 'enable volunteer', 'volunteer', 'vision strategy', 'DataRobot committed', 'committed working', 'Transformation achieving', 'leadership role', 'committed principle', 'domestic partnership', 'partnership status', 'great platform career growth product leadership role', 'community', 'organization pioneering', 'ADS organization', 'organization focuses', 'focuses providing', 'accountable driving', 'partnering stakeholders', 'progress programs', 'responsibilities passionate', 'stakeholders', 'vocal advocacy', 'awareness adoption', 'commit mission', 'GP1875 Commitment', 'Commitment Equal', 'Coinbase committed', 'committed diversity', 'diversity workforce', 'workforce proud', 'committed providing', 'major mainstream awareness adoption cryptocurrency', 'mission - focused approach work', 'GP1875 Commitment Equal Opportunity Coinbase', 'driven organization', 'spearhead process', 'producing sustainable', 'sustainable ethical', 'mission accelerate', 'inclusion broadening', 'strongly encourage', 'sustainable ethical food', 'mission', 'efforts', 'involved responsible', 'adoption success', 'opportunities regard', 'promote individuals', 'strive foster', 'foster inclusive', 'foster inclusive working environment', 'commitment', 'engage mission', 'mission fundamentally', 'support Active', 'responsible shepherding', 'shepherding development', 'proven success', 'success ownership', 'operational excellence', 'proven success ownership', 'sharing vision AWS senior leadership', '- mentoring', 'supported established', 'people organization', 'organization tech', 'tech leadership', 'initiatives numerous', 'supporting broader', 'dedicated accelerating', 'grow fostering', 'fostering direct', 'partners managed', 'partners']
# ++++++++++++++++
# cluster 2 , values : ['environment celebrates', 'celebrates knowledge', 'establish brings', 'brings energy', 'technology brings', 'brings availability', 'workforce makes', 'role unique', 'propels reality', 'enriches diversity', 'research propels reality', 'celebrate makes', 'makes unique', 'brings workplace', 'person brings', 'brings traditional', 'leverages rich']
# ++++++++++++++++
# cluster 3 , values : ['newest hybrid', 'hybrid storage', 'provides hybrid', 'hybrid object', 'programming model', 'model features', 'delivering hybrid', 'generation hybrid', 'hybrid computing', 'built scaled', 'newest hybrid storage service', 'hybrid object storage', 'hybrid storage platform Outposts', 'object storage generation hybrid computing platform', 'feature definition', 'synthesizing variety', 'computing represents', 'deployment model', 'model imaginable', 'cross functional', 'generation distributed', 'proven , modern , integrated technology', ', deployment model imaginable', 'based offerings', 'DataRobot AI platform heterogeneous infrastructure landscape', 'Subscription Models', 'consistent digital', 'digital foundation', 'based characteristics', 'models continue', 'model improvements', 'definition specification', 'drive ML model improvements', 'platform product definition specification', 'carbon footprint', 'transforming cars', 'delivering generation', 'generation Benchling', 'generation', 'pioneered mobile', 'mobile sensing', 'Powered mobile sensing', 'core Compute', 'alongside distributed', 'making computing', 'hybrid multi', 'private , hybrid multi - cloud environments', 'future digital', 'drives definition', 'support models', 'growing Iterative', 'growing Iterative Scopes team', 'new capabilities', 'capabilities ground', 'machine learning driven products', 'company hybrid', 'hybrid customer', 'model allows', 'company hybrid customer - data marketing - platform model', 'Powered threat', 'centerpiece adaptive', 'ecosystem features', 'lake leverages']
# ++++++++++++++++
# cluster 4 , values : ['Seaport office', 'Center U.S.', 'security administration', 'Responsibilities U.S.', 'U.S. DataRobot', 'United States', 'States Department', 'Department Labor', 'Labor EEO', 'United States Department', 'Core Responsibilities U.S.', 'performed United', 'States Canada', 'Biden Administration', 'Administration issuing', 'vaccination U.S.', 'U.S. based', 'federal contractors', 'civil union', 'union domestic', 'present military', 'local law', 'United States Canada', 'U.S. based VMware employees', 'marital , civil union domestic partnership status', 'state local', 'California Consumer Privacy Act', 'proud Federal', 'Federal Government', 'Government contractor', 'Additionally , OpenText , proud Federal Government contractor']
# ++++++++++++++++
# cluster 5 , values : ['Amazon S3', 'services Amazon', 'levels Amazon', 'Amazon tenures', 'Amazon culture', 'trust Amazon', 'Amazon committed', 'Amazon equal', 'Amazon Dev', 'Amazon S3 Outposts', 'scaled services Amazon', 'Amazon culture inclusion', 'like Amazon', 'Amazon GuardDuty', 'Amazon Macie', 'Amazon Inspector', 'Amazon Detective', 'vision Amazon', 'manager Amazon', 'opportunity Amazon', 'LinkedIn Facebook', 'Thrilled Amazon', 'experience Amazon', 'Amazon customers', 'Amazon.com Services', 'Amazon.com Services LLC Job ID', 'Alexa experience Amazon customers', 'join Amazon', 'Amazon Athena', 'Amazon Athena Team', 'DESCRIPTION Amazon', 'products Amazon', 'buy online', 'supports Amazon', 'Amazon Product', 'span Amazon', 'Amazon consumer', 'business Amazon.com', 'Amazon Private', 'Amazon Devices', 'Amazon party', 'businesses Amazon', 'Amazon inception', 'career Amazon', 'Amazon product', 'Amazon.com', 'Amazon Private Brands', 'Amazon , Foods', 'Amazon Product Assurance', 'Amazon consumer retail business Amazon.com', 'Amazon party fulfillment business']
# ++++++++++++++++
# cluster 6 , values : ['Description seeking', 'technical details', 'like request', 'code reviews', 'addresses current', 'availability', 'functionally address', 'address myriad', 'receiving available', 'evaluate requests', 'additional information', 'submitted handled', 'receive consideration', 'notices clicking', 'Verify program', 'nature request', 'request contact', 'contact information', 'site click', 'contact accommodations@', 'information request', 'notice outlining', 'feedback', 'E - Verify program certain locations', 'nature request contact information', 'coinbase.com additional information request accommodations', 'know contacting', 'Information Company', 'Company Information', 'Information Management', 'job Opentext - Information Company Information Company', 'contact', 'subject Executive Order _', 'Summary DESCRIPTION', 'query service', 'details ideas', 'meet deadlines', 'deadlines', 'match description', 'connection online', 'information available', 'information']
# ++++++++++++++++
# cluster 7 , values : ['defending cloud', 'innovating cloud', 'cloud security', 'opportunity cloud', 'cloud computing', 'incredible opportunity cloud computing', 'hybrid cloud', 'cloud workloads', '+ clouds', 'multi cloud', 'cloud deployment', 'cloud integrations', 'strategy cloud', 'better cloud', 'leader virtualization', 'virtualization cloud', 'cloud infrastructure', 'thrive Cloud', 'Cloud Era', 'VMware leader virtualization cloud infrastructure solutions', 'analytics', 'leader cloud', 'cloud software', 'computing invisible', 'cloud environments', 'integrated cloud']
# ++++++++++++++++
# cluster 8 , values : ['experienced product', 'product leader', 'lead product', 'product management', 'Product Management', 'entrepreneurial product', 'engineers product', 'product managers', 'experienced product leader', 'Product Management AWS opportunity', 'entrepreneurial product leader', 'senior product', 'product manager', 'product vision', 'principal product', 'deliver product', 'product roadmap', 'consumer product', 'product market', 'product roadmap customers', 'consumer product market', 'leading product', 'product portfolio', 'drives product', 'product strategy', 'Product Manager', 'experienced Product', 'Product Managers', 'industry - leading product portfolio', 'engineering delivery Veritas products', 'Principal Product', 'influence product', 'Platform Product Management', 'intersection product', 'strategy product', 'product operations', 'growth product', 'product leadership', 'Marketing Product', 'Product Management team', 'scale product', 'product Customer', 'entire product', 'product lifecycle', 'product definition', 'driving product', 'product innovations', 'demonstrated product', 'product professional', 'seasoned product', 'product launched', 'product', 'Compute product', 'product suite', 'Lead Product', 'develops product', 'delivery product', 'product releases', 'cycle product', 'ensure product', 'Catalogue product', 'plan product', 'features product', 'Agile product', 'product backlogs', 'product architects', 'Lead Product Manager Retail / Supply Chain experience', 'Lead Product Manager', 'definition delivery product', 'Active Catalogue product portfolio', 'Technical Product', 'passionate product', 'successful product', 'product launches', 'passionate product management leader', 'strategic product', 'product team', 'global product', 'Product Assurance', 'role product', 'product owner', 'truth product', 'product compliance', 'aspects product', 'work product', 'product tech', 'product engineering', 'tech product', 'managing product', 'product roadmaps', 'global product team', 'job Product', 'Product team', 'best product', 'product possible', 'Director Product', 'Product join', 'Group Product', 'guide product', 'product development', 'Group Product Managers', 'product development concept launch']
# ++++++++++++++++
# cluster 9 , values : ['details working', 'working closely', 'value work', 'need work', 'work home', 'office hours', 'Work / Life Balance team', 'success working', 'working backwards', 'work closely', 'able work', 'work effectively', 'Working closely', 'impact work', 'hours spend', 'home work', 'flexibility working', 'working hours', 'hours encourage', 'balance work', 'work personal', 'balance work personal lives', 'Managers working', 'working cross', 'working providing', 'flexibility work', 'Professional Time', 'work seamlessly', 'problems working', 'working cutting', 'approach work', 'Future Work', 'Work thought', 'years experience', 'expected work', 'work remotely', 'resume work', 'work respective', 'place work', 'Companies Work', 'inclusive working', 'great work', 'work safe', 'excited work', 'want work', 'work alongside', 'morning excited work', 'works closely', 'inclusive work', 'maintaining working', 'Want work', 'work cutting', 'work core', 'work hard', 'work maintain', 'interact work', 'work emerging', 'ability work', 'work independently', 'independently time', 'experience working', 'working tech', 'Managers work', 'work cross']
# ++++++++++++++++
# cluster 10 , values : ['generally core', 'inclusion reinforced', 'focused security', 'security investigation', 'investigation response', 'vision key', 'key set', 'problems demonstrated', 'dozens internal', 'external partners', 'role inherently', 'impact role', 'requires strong', 'levels tenures', 'flow establish', 'security investigation response', 'secure critical', 'critical assets', 'global leader Identity Security', 'costs maintain', 'maintain regulatory', 'regulatory readiness', 'Protection Group', 'deliver strategy', 'current future data issues', 'mission - critical workloads', 'operations DataRobot', 'lead delivery', 'associated ecosystem', 'needs internal', 'Core Responsibilities', 'prevents receiving', 'Kubernetes associated ecosystem', 'influence product vision strategy cloud - based offerings', 'internal engineering teams external customers', 'selected candidate consideration', 'defining delivering', 'strategic priority', 'priority operate', 'operate consumption', 'role performed', 'barriers compromise', 'value execution', 'consistent local', 'VMware strategic priority operate consumption - obsessed SaaS company', 'role unique intersection product management', 'barriers', 'execution', 'integrity', 'assurance launch', 'involves regular', 'regular communication', 'management status', 'risks change', 'change control', 'defining strategy', 'strategy measuring', 'monitoring day', 'stakeholder interaction', 'accountable driving entire product lifecycle', 'control', 'leading compliant', 'multiple successful', 'increase economic', 'regardless role', 'desire capacity', 'relevant role', 'manner consistent', 'Pay Transparency', 'program certain', 'General Data Protection Regulation', 'increase', 'capacity', 'way relevant role', 'Global Data Privacy Notice Job Candidates', 'energy reduce', 'reduce carbon', 'energy options', 'dramatically changing', 'use conduct', 'responsible setting', 'best practices', 'practices safety', 'safety protocols', 'best practices safety protocols', 'personal safety', 'improve safety', 'safety millions', 'directly involved', 'contribute key', 'measure adoption', 'success rates', 'role directly', 'scale private', 'drive measure adoption success rates', 'releases responsible', 'strategy Active', 'role requires', 'background required', 'implementation strategic', 'interaction sales', 'Policy provides', 'selection process', 'Lead Product Manager responsible development implementation strategic plan product', 'close interaction sales', 'cost effective', 'prioritizing existing', 'existing versus', 'shown demonstrated', 'managing high', 'safety paramount', 'role report', 'Risk Security', 'inception rapid', 'role provide', 'universal safety', 'safety decisions', 'changing regulatory', 'regulatory landscape', 'fulfillment operations', 'time constraints', 'constraints meet', 'Prior functional', 'strategy preferred', 'Amazon Product Assurance , Risk Security', 'environment customer safety paramount', 'role product owner universal safety compliance store', 'downstream systems single source truth product compliance safety decisions', 'serve - changing regulatory landscape', 'Prior functional experience working tech product management', 'prospect communications', 'direct relationships', 'transactional behavioral data power highly - targeted customer prospect communications', 'threat intelligence']
# ++++++++++++++++
# cluster 11 , values : ['employees', 'DataRobot employees', 'employees fully', 'based employees', 'employees federal', 'contractors subcontractors', 'VMware employees', 'employees need', 'opportunity employees', 'employees providing', 'providing employees', 'employees work', 'employees protected', 'U.S. based employees federal contractors subcontractors', 'million accounts', 'expect employees', 'employees commit', 'million', 'Benchling employees', 'employees expected', 'safe employees', 'employees resume', '+ employees', 'employees worldwide', 'requiring employees', 'New employees', 'employees joining']
# ++++++++++++++++
# cluster 12 , values : ['building environment', 'like environment', 'paced environment', 'environment requires', 'projects based', 'complex tasks', 'projects', 'responsible building', 'building architectural', 'architectural foundational', 'infrastructure landscape', 'native architecture', 'architecture execute', 'work environment', 'environment free', 'environment', 'project management', 'working environment', 'environment enables', 'welcoming environment', 'responsible development', 'development implementation', 'development leads', 'environment simply', 'environment inclusive', 'development', 'inclusive work environment', 'development high', 'architectural improvements', 'build environment', 'involves building', 'building interactive', 'complex initiatives', 'development concept']
# ++++++++++++++++
# cluster 13 , values : ['embrace differences', 'culture inclusion', 'led affinity', 'affinity groups', 'Race Ethnicity', 'gender diversity', 'basis race', 'gender identity', 'sexual orientation', 'differences', 'Conversations Race Ethnicity', 'ethnicity', 'backwards ambiguous', 'national origin', 'leader Identity', 'Identity Security', 'offering identity', 'value uniqueness', 'gender expression', 'status individual', 'religion', 'principle equal', 'regard race', 'religion belief', 'social ethnic', 'ethnic origin', 'HIV Status', 'identity and/or', 'and/or expression', 'history genetic', 'family parental', 'parental status', 'national , social ethnic origin', 'expression', 'family parental status', 'expression identity', 'orientation basis', 'criminal histories', 'histories manner', 'gender expression identity', 'sexual orientation basis', 'diversity inclusion', 'value diversity', 'marital status', 'bias action', 'identity expression', 'status category', 'Equity Diversity', 'Diversity Policy', 'regardless culture', 'gender identification', 'family status', 'certainty ambiguous']
# ++++++++++++++++
# cluster 14 , values : ['storage platform', 'platform Outposts', 'computing platform', 'Services Platform', 'Platform addresses', 'Native Platform', 'Platform Global', 'Global Platform', 'Platform team', 'platform heterogeneous', 'member Platform', 'Platform Product', 'platform infrastructure', 'Cloud - Native Platform Global Platform team', 'great platform', 'platform career', 'build platform', 'platform service', 'platform product', 'cryptocurrency platform', 'platform serving', 'world leading compliant cryptocurrency platform', 'platform', 'platform AOS', 'features platform', 'single platform', 'platform manage', 'key marquis features platform', 'automation platform', 'platform dedicated', 'platform model', 'ad platforms']
# ++++++++++++++++
# cluster 15 , values : ['job VERITAS', 'VERITAS Veritas', 'Veritas solves', 'Veritas Enterprise', 'Veritas supports', 'delivery Veritas', 'Veritas products', 'includes NetBackup', 'Manager NetBackup', 'market NetBackup', 'Veritas', 'NetBackup', 'serverless SQL', 'Unilever', 'job Sophos', 'Sophos worldwide', 'Sophos delivers', 'Sophos provides', 'Sophos Central', 'Sophos sells', 'Sophos major']
# ++++++++++++++++
# cluster 16 , values : ['equal opportunity', 'opportunity employer', 'employer discriminate', 'discriminate basis', 'equal opportunity employer', 'Amazon equal opportunity employer', 'candidate consideration', 'Equal Employment', 'Employment Opportunity', 'Opportunity Affirmative', 'Affirmative Action', 'Action employer', 'discriminate based', 'applicants physical', 'Equal Employment Opportunity Affirmative Action', 'DataRobot proud Equal Employment Opportunity Affirmative Action employer', 'date employment', 'employment date', 'Equal Opportunity', 'Opportunity Employer', 'Employer Prohibits', 'Prohibits Discrimination', 'Discrimination Harassment', 'Harassment Kind', 'equal employment', 'employment opportunity', 'free discrimination', 'discrimination harassment', 'employment decisions', 'individual qualifications', 'tolerate discrimination', 'harassment based', 'encourages applicants', 'applicants ages', ', date employment date', 'Equal Employment Opportunity Statement', 'VMware Equal Opportunity Employer', 'committed principle equal employment opportunity employees', 'free discrimination harassment', 'applicants', 'qualified applicants', 'applicants receive', 'consideration employment', 'employment regard', 'consider employment', 'employment qualified', 'applicants criminal', 'Employee Rights', 'Rights Equal', 'Opportunity Law', 'employment process', 'Candidates Applicants', 'Applicants Depending', 'Global Data Privacy Notice Job Candidates Applicants', 'proud Equal Opportunity Employer', 'consideration employment regard race', 'employment', 'Employee Rights Equal Employment Opportunity Law', 'reasonable accommodation disability employment process', 'encourage apply', 'employer value', 'applicants arrest', 'arrest conviction', 'conviction records', 'Chance Ordinance', 'equal opportunity employer value diversity company', 'based insurance', 'Qualified applicants', 'applicants considered', 'considered employment', 'employment opportunities', 'individuals solely', 'solely basis', 'basis qualifications', 'free unlawful', 'unlawful discrimination', 'intimidation harassment', 'Nutanix Equal Employment Opportunity', 'Nutanix Equal Employment Opportunity ( U.S. ) Affirmative Action employer', 'solely basis qualifications job', 'Employment Equity', 'OpenText Equal Opportunity Employer', 'Employment Equity Diversity Policy']
# ++++++++++++++++
# cluster 17 , values : ['collaborate engineering', 'closely engineering', 'engineering', 'engineer enable', 'engineering delivery', 'internal engineering', 'compromise engineer', 'Artificial Intelligence', 'engineers scientists', 'science initiatives', 'Artificial Intelligence ,', 'Alexa engineers scientists', 'edge data science initiatives', 'Crop science', 'science synthetic', 'synthetic biology', 'biology producing', 'accelerate research', 'research propels', 'scientists world', 'conduct research', 'renowned research', 'research institutes', 'Crop science synthetic biology', 'scientists', 'world renowned research institutes', 'artificial intelligence', 'behavioral science', 'core engineering', 'previous engineering', 'engineering experience', 'fluently engineers', 'engineers stakeholders', 'engineers field', 'scientists org']
# ++++++++++++++++
# cluster 18 , values : ['join Boston', 'located Boston', 'Boston Seaport', 'Boston Seattle', 'Seattle', 'California Consumer', 'California', 'limited San', 'San Francisco', 'Francisco Fair', 'limited San Francisco Fair Chance Ordinance', 'headquartered San', 'San Jose', 'headquartered San Jose', 'January']
# ++++++++++++++++
# cluster 19 , values : ['Outposts', 'translating disruptive', 'adept synthesizing', 'centric thrive', 'prioritization', 'distributed workforces', 'workloads DevOps', 'DevOps lifecycle', 'workforces', 'critical workloads', 'workloads highly', 'eDiscovery platform', 'eDiscovery', 'Archiving', 'roadmap', 'observability', 'VMware leader', 'enterprise SMB', 'accelerating VMware', 'achieving VMware', 'VMware strategic', 'VMware Equal', 'VMware committed', 'decisions VMware', 'VMware tolerate', 'VMware encourages', 'stakeholders Alexa', 'compliant cryptocurrency', 'advocacy blockchain', 'blockchain technology', 'adoption cryptocurrency', 'crypto blockchain', 'vocal advocacy blockchain technology', 'Biofuels biomaterials', 'biomaterials transforming', 'telematics analytics', 'incentivize safer', 'Cambridge Mobile Telematics', 'native hypervisor', 'hypervisor AHV', 'Prism centralized', 'problem solvers', 'solvers entrepreneurial', 'disrupting computing', 'hyperconverged infrastructure', 'Bloomberg', 'native hypervisor AHV', 'solvers', 'managing Agile', 'evaluators', 'potentials', 'Agile product backlogs', 'Iterative Scopes', 'Iterative', 'analyze petabytes', 'ground performant', 'performant cost', 'transactional behavioral', 'generation cybersecurity', 'networks endpoints', 'endpoints ransomware', 'range cyberattacks', 'adaptive cybersecurity', 'cybersecurity ecosystem', 'cybersecurity vendors', 'networks endpoints ransomware', 'Sophos Central – centerpiece adaptive cybersecurity ecosystem']
# ++++++++++++++++
# cluster 20 , values : ['seeking experienced', 'leader join', 'looking entrepreneurial', 'leader passionate', 'Successful candidates', 'candidates able', 'joining experienced', 'members truly', 'truly enjoy', 'enjoy mentoring', 'members seek', 'learn curious', 'earn trust', 'need experienced', 'help lead', 'looking experienced', 'successful candidate', 'candidate highly', 'ideal candidate', 'candidate excited', 'excited incredible', 'incredible opportunity', 'members enjoy', 'encourage find', 'looking experienced product leader passionate solving customer problems', 'successful candidate highly analytical organized , able work effectively start - like environment', 'blogs follow', 'follow Twitter', 'opportunity join', 'highly experienced', 'proud Equal', 'feel productive', 'opportunities people', 'Opportunity Statement', 'come join', 'join ADS', 'candidate creative', 'opportunity requires', 'opportunity', 'proud offer', 'look hires', 'candidate thrive', 'seek people', 'Opportunity Coinbase', 'thought leader', 'Want spearhead', 'imagine deliver', 'looking seasoned', 'believe member', 'Fair Chance', 'looking seasoned product leader _', 'Join mark', 'hire promote', 'morning excited', 'want engage', 'looking Lead', 'believe qualify', 'Interesting helping', 'Come join', 'looking candidate', 'candidate obsessed', 'leader need', 'looking strong', 'need passionate', 'leader dives', 'want enjoy', 'exceptionally talented', 'chance challenging', 'great opportunity', 'great opportunity build career Amazon product leader', 'believe deserves', 'deserves fair', 'success appreciate', 'hope consider', 'giving valuable']
# ++++++++++++++++
# cluster 21 , values : ['management AWS', 'AWS newest', 'AWS Outposts', 'managed AWS', 'AWS infrastructure', 'S3 Outposts', 'premises S3', 'S3 programming', 'Management AWS', 'AWS opportunity', 'new AWS', 'AWS business', 'Culture AWS', 'product management AWS', 'new AWS business', 'Description AWS', 'AWS External', 'AWS Security', 'internal AWS', 'AWS services', 'teams AWS', 'levels AWS', 'AWS leadership', 'AWS Security Hub', 'levels AWS leadership', 'integrations AWS', 'cloud integrations AWS', 'field AWS', 'vision AWS', 'AWS senior', 'access engineers field AWS']
# ++++++++++++++++
# cluster 22 , values : ['storage service', 'object storage', 'storage enabling', 'store retrieve', 'storage generation', 'Dev Center', 'fully managed AWS infrastructure services customers - premises data centers', 'External Security', 'Security Hub', 'Description AWS External Security Services', 'cloud - based applications services', 'internal AWS services external partners', 'privileged access', 'access management', 'Centered privileged access management', '+ storage', 'storage targets', 'defined Storage', 'Backup Exec', 'Enterprise Vault', 'Protection Backup', 'distributed multi', 'Veritas Enterprise Data Services Platform', 'market leader Software - defined Storage', 'deployment operations', 'includes infrastructure', 'resource management', 'storage', 'private / public / hybrid cloud deployment experience', 'foundation securely', 'securely delivering', 'Alexa Data Services ) team', 'entire suite', 'access screen', 'warehouse internal', 'user base', 'mobile usage - based insurance', 'distributed storage', 'centralized management', 'distributed storage platform AOS', 'Prism centralized management', 'Supply Chain', 'catalogues integration', 'supply chain', 'office virtual', 'supply chain solutions', 'scalable distributed', 'development high - performance , scalable distributed services data pipeline', 'access engineers', 'big data , analytics , machine learning', 'enables supports', 'compliance store', 'downstream systems', 'systems single', 'single source', 'robust closed', 'loop tools', 'includes retail', 'robust closed loop tools', 'use transactional', 'secure users', 'single integrated', 'management console', 'features centralized', 'single integrated cloud - based management console']
# ++++++++++++++++
# cluster 23 , values : ['mentoring - - sessions', 'Inclusive Team Culture AWS', 'ExternalSecurityServices - Amazon Dev Center', 'trust CyberArk', 'CyberArk help', 'learn CyberArk', 'read CyberArk', 'CyberArk blogs', 'Twitter @CyberArk', 'CyberArk', 'Fortune _', 'EV.cloud', 'DataRobot responsible', 'Kubernetes associated', 'fully vaccinated', 'vaccinated COVID-_NUMBER', 'available COVID-_NUMBER', 'DataRobot proud', 'EEO poster', 'poster EEO', 'poster supplement', 'DataRobot', 'Kubernetes', 'COVID-_NUMBER', 'available COVID-_NUMBER_ vaccination', 'mandates COVID-_NUMBER', 'vaccinated January', 'January 4th', 'COVID-_NUMBER_ vaccination', 'fully vaccinated January 4th', 'Alexa engineers', 'improve ML', 'ML models', 'evolve Alexa', 'Alexa experience', 'PMT lead', 'drive ML', 'ML model', 'Alexa Organization', '- Amazon.com Services LLC Job ID', 'Coinbase built', 'cryptoeconomy increase', 'hires Coinbase', 'Coinbase consider', 'Coinbase participates', 'participates E', 'mail accommodations@', 'accommodations@ coinbase.com', 'coinbase.com let', 'coinbase.com additional', 'Coinbase', '_NUMBER_ million accounts', 'cryptoeconomy', 'Overview Perch', 'BlueWave Solar', 'Aquent looks', 'Benchling mission', 'use Benchling', 'Benchling central', 'large scrum', '+ years', 'Benchling welcomes', 'Benchling', 'CMT world', 'Cambridge Mobile Telematics ( CMT ) mission world roads drivers', 'rideshares', 'Nutanix Karbon', 'responsible Kubernetes', 'Kubernetes container', 'Karbon core', 'plus Prism', 'key marquis', 'marquis features', 'SEs sales', 'LifeAtNutanix things', 'makes Nutanix', 'Nutanix great', 'recognized Bloomberg', 'pioneer hyperconverged', 'use Nutanix', 'Nutanix Equal', 'enables Nutants', 'Nutants great', 'contacting CandidateAccommodationRequests@nutanix.com', 'Nutanix', 'Nutanix Karbon core Compute product suite', 'Nutanix passionate team _', '( “ Nutants', 'heartbeat #', 'Bloomberg _', 'CandidateAccommodationRequests@nutanix.com', 'EnergySage place', 'mission OpenText', 'OpenText create', 'OpenText looking', 'Active Catalogue', 'OpenText Equal', 'joining OpenText', 'OpenText required', 'form accommodationrequests@opentext.com', 'OpenText', '( office', 'January _', 'ML plus', 'Athena makes', '- Amazon Dev Center U.S. , Inc.', 'A1763341', 'closely PARS', 'Risk Security ( PARS ) team', 'A1742721', 'Klaviyo continuously', 'functionally guide', 'Klaviyo value', 'Klaviyo world', 'Klaviyo makes', 'like Unilever', 'Proof Huckberry', 'Huckberry sell', 'sell Klaviyo', 'Klaviyo', 'Klaviyos', '( Klaviyos', 'Living Proof Huckberry', 'advanced cyberthreats', 'SophosLabs SophosAI', 'phishing wide', 'open APIs', 'APIs available', 'cyberthreats', 'SophosLabs', 'Sophos major hubs globe']
# ++++++++++++++++
# cluster 24 , values : ['job Description', 'Inc. Job', 'care career', 'job CyberArk', 'job Job', 'Job Description', 'job Job Description', 'job enjoy', 'job requirements', 'Job responsibilities', 'LLC Job', 'job Coinbase', 'Notice Job', 'Job Candidates', 'job applicants', 'data job applicants', 'job Define', 'job coming', 'qualifications job', '% qualifications job', 'job Cambridge', 'job Senior', 'job filled', 'job good', 'job Opentext', 'job looking', 'job looking Technical Product Manager previous engineering experience', 'Job Summary', 'job Job Summary DESCRIPTION', 'job Job Summary DESCRIPTION Amazon', 'traditional job', 'traditional job requirements']
# ++++++++++++++++
# cluster 25 , values : ['request accommodation', 'requests accommodation', 'reasonable accommodations', 'accommodations applicants', 'required accommodations', 'reasonable accommodation', 'accommodation employees', 'reasonable accommodation employees', 'accommodations individuals', 'accommodation disability', 'request accommodations', 'reasonable accommodations individuals disabilities', 'require accommodations', 'accommodations selection', 'accommodations selection process']
# ++++++++++++++++
# cluster 26 , values : ['able build', 'build strategic', 'managers built', 'develop grow', 'develop better', 'eager build', 'scientists build', 'build improve', 'helping build', 'build cryptoeconomy', 'capacity build', 'build share', 'systems build', 'build grow', 'builders problem', 'builders', 'efforts build', 'build inclusive', 'success building', 'building strong', 'help build', 'opportunity build', 'build career', 'developers build', 'developers', 'ways build', 'build deliver']
# ++++++++++++++++
# cluster 27 , values : ['team responsible', 'development teams', 'engineering team', 'team drive', 'experienced team', 'team engineers', 'teammate enthusiastic', 'diverse team', 'team peers', 'Balance team', 'team puts', 'entire team', 'team co', 'Growth team', 'team dedicated', 'new team', 'team members', 'team broad', 'Inclusive Team', 'Team Culture', 'remind team', 'closely engineering team drive delivery', 'experienced team engineers product managers', 'Mentorship Career Growth team', 'new team members', 'team growing', 'executive teams', 'teams bring', 'closely teams', 'help team', 'team member', 'Mentorship & Career Growth team', 'help team member', 'Exec team', 'join team', 'team highly', 'global team', 'team leading', 'winning team', 'opportunity join team', 'team DataRobot', 'Management team', 'engineering teams', 'teams external', 'team coordination', 'team building', 'Cross - team coordination', 'role team', 'play championship', 'championship team', 'lead team', 'team delivering', 'scrum team', 'team Benchling', 'grow team', 'member team', 'team enriches', 'teams Nutanix', 'passionate team', 'amazing team', 'team smart', 'team leads', 'market team', 'team ensure', 'Scopes team', 'team help', 'Athena Team', 'entrepreneurial team', 'team operates', 'teams dive', 'small , entrepreneurial team', 'team enables', 'team owns', 'team role', 'team Seattle', 'tech teams', 'PARS teams', 'teams globally', 'teams applied', 'chance challenging strategic product team', 'established tech teams', 'work product tech teams', 'team Klaviyo', 'growing team', 'team expertise', 'develop team', 'team Group', 'job Product team Klaviyo', 'rapidly growing team expertise', 'team Group Product Managers']
# ++++++++++++++++
# cluster 28 , values : ['chapters globally', 'redefining enterprises', 'enterprises defending', 'bring consumer', 'market develop', 'enterprises', 'global leader', 'world leading', 'leading organizations', 'market leader', 'forefront accelerating', 'innovation globe', 'major mainstream', 'countries', 'consumer energy', 'leader industry', 'leader industry technology - driven organization', 'biotech fundamentally', 'include pharmaceutical', 'pharmaceutical giants', 'leading biotechs', 'diversity company', 'biotech', 'leading telematics', 'millions', ', CMT world leading telematics analytics provider insurers', 'automakers', 'Companies Watch', 'Best Companies', 'Nutanix global', 'Companies world', 'Companies', 'understanding retail', 'retail catalogues', 'relationships market', 'awareness market', 'market needs', 'defining market', 'market requirements', 'awareness market needs', 'healthcare tech', 'report global', 'consumer retail', 'Private Brands', 'emerging businesses', 'rapid growth', 'established tech', 'list global', 'global stakeholders', 'broader businesses', 'retail tech', 'growing list global stakeholders', 'rapidly growing', 'accelerating revenue', 'allows companies', 'companies grow', 'innovative companies', 'companies like', 'Klaviyo world - leading marketing automation platform', 'companies', 'NUMBER_ innovative companies', 'worldwide leader', 'organizations millions', 'millions consumers', 'countries today', 'broad portfolio', 'major hubs', 'hubs globe', 'NUMBER_ organizations millions consumers']
# ++++++++++++++++
# cluster 29 , values : ['shape object', 'position located', 'position', 'unique intersection', 'work location', 'location feel', 'locations operate', 'flexibility work location', 'position involves', 'look signals', 'signals candidate', 'clicking corresponding', 'corresponding links', 'certain locations', 'Depending location', 'locations available', 'signals', 'vision direction', 'direction large', 'respective office', 'office locations', 'work respective office locations', 'location', 'maintains close', 'provides direction', 'direction maintaining', 'direction', 'operates independently', 'hidden signals', 'closed loop']
# ++++++++++++++++
# cluster 30 , values : ['Outposts provide', 'provide fully', 'delivery features', 'features delight', 'high value', 'innovative benefit', 'benefit offerings', 'innovative benefit offerings', 'set features', 'expanded coverage', 'capabilities high', 'high quality', 'high visibility', 'visibility high', 'high impact', 'delivering highest', 'highest quality', 'offer flexibility', 'product vision key set features', 'high visibility high impact role', 'highest quality services', 'flexibility', 'CyberArk provides', 'provides comprehensive', 'offer proven', 'highly available', 'delivery high', 'providing reasonable', 'supplement additional', 'reliability', 'provide great', 'form flexible', 'provide reasonable', 'flexible , consistent digital foundation', 'providing ground', 'quality assurance', 'programs ideal', 'professional superior', 'requires excellent', 'quality assurance launch world', 'offer entire', 'sustained high', 'high performance', 'sustained high performance', 'options accessible', 'including limited', 'driving quality', 'quality', 'addition superior', 'superior track', 'display superior', 'provided reasonable', 'addition', 'definition delivery', 'delivery support', 'packaging features', 'required provide', 'provide proof', 'exhibit excellent', 'excellent judgment', 'store provide', 'provide downstream', 'deliver best', 'value unique', 'delivers broad', 'wide range', 'provides single', 'wide range cyberattacks']
# ++++++++++++++++
# cluster 31 , values : ['excited growing', 'growing new', 'looking new', 'new teammate', 'supporting new', 'host annual', 'annual ongoing', 'growing need', 'grow new', 'new members', 'current future', 'bringing generation', 'bringing latest', 'latest advances', 'enjoy new', 'new opportunity', 'unlock new', 'new opportunities', 'engineer new', 'new ways', 'engineer new ways', 'launch world', 'Perch new', 'new kind', 'coming years', 'future challenges', 'alongside amazing', 'redefine future', 'roadmap meet', 'prior joining', 'joining approved', 'join growing', 'growing year', 'developing new', 'versus new', 'growing list', 'join rapidly', 'bringing new', 'concept launch', 'popular big', 'popular big - tech ad platforms', 'today advanced']
# ++++++++++++++++
# cluster 32 , values : ['successful products', 'products delight', 'integrate products', 'products Detective', 'quality products', 'products applications', 'products', 'high quality products applications customers', 'suite products', 'products helping', 'multiple successful products', 'entire suite products', 'container products', 'products Nutanix', 'responsible Kubernetes container products', 'carry products', 'products customers', 'safe products', 'technology products', 'products span', 'driven products', 'products identify', 'products supported', 'new products', 'products market', 'new products market', 'advanced products', 'products services', 'sells products', 'broad portfolio advanced products services']
# ++++++++++++++++
# cluster 33 , values : ['MA office', 'DataRobot AI', 'AI platform', 'cloud AI', 'Amazon AI', 'AI organization', 'world AI', 'AI technology', 'world AI technology', 'tech AI', 'AI machine']
# ++++++++++++++++
# cluster 34 , values : ['office lead', 'senior members', 'protected veteran', 'veteran status', 'experienced senior', 'manager help', 'Detective lead', 'rounded engineer', 'principal product manager', 'senior member', 'selected candidate', 'Principal Product Manager', 'senior member Platform Product Management team DataRobot', 'veteran', 'reporting Director', 'issuing Executive', 'Executive Order', 'Management Manager', 'Manager Professional', 'Director', 'Manager PMT', 'communication senior', 'senior management', 'management executive', 'executive presentation', 'regular communication senior management status', 'project management executive presentation', 'Product Manager PMT lead', 'parent company', 'Manager Nutanix', 'job Senior / Principal Product Manager Nutanix Karbon', 'Manager Retail', 'Manager develops', 'Manager drive', 'Manager responsible', 'subject Executive', 'Manager previous', 'senior leadership', 'management leader', 'technical Principal', 'Manager join', 'respective executive', 'strong technical Principal Product Manager', 'legal respective executive teams', 'looking Senior', 'Senior Director', 'Senior Director Product']
# ++++++++++++++++
# cluster 35 , values : ['drive delivery', 'Life Balance', 'puts high', 'life balance', 'broad mix', 'mix experience', 'high value work - life balance', 'team broad mix experience levels', 'lead feature', 'inherently cross', 'feel impact', 'thrive fast', 'judgment solid', 'live balance', 'spend home', 'energy parts', 'parts life', 'believe striking', 'striking right', 'right balance', 'balance personal', 'professional life', 'life critical', 'critical life', 'long happiness', ', lead feature definition', 'fast - paced environment', 'broad mix experience levels tenures', 'better - rounded engineer', 'high value work - live balance', 'energy parts life', 'right balance personal professional life critical life - long happiness fulfillment', 'human machine', 'issues end', 'Group drives', 'leading edge', 'edge bringing', 'causes close', 'close heart', 'heart enable', 'makes winning', 'end - - end', 'cross functional , diverse , global team', 'journey better', 'based race', 'lead delivery high - performance , innovative , multi - cloud AI platform infrastructure roadmap', 'journey better cloud - native architecture', 'world class', 'power unlock', 'core people', 'past present', 'cutting edge', 'ground truth', 'day life', 'life Principal', 'lead drive', 'drive cutting', 'driving entire', 'lead driving', 'end end', 'end ownership', 'day day', 'day progress', 'built world', 'played major', 'expect sustained', 'performance play', 'energy start', 'clean energy', 'force good', 'mission clean energy options', 'year track', 'track record', 'fast - growing , innovative , organization _NUMBER_ - year track record', 'way live', 'cars drive', 'world use', 'setting vision', 'experience deep', 'following best', 'world roads', 'roads drivers', 'measure driving', 'safer driving', 'crashes real', 'real time', 'millions drivers', 'drivers day', 'day world', 'safety millions drivers day world', 'drive measure', 'great place', 'growing fast', 'fast disrupting', 'superior track record', 'Nutants great work safe welcoming environment', 'wake morning', 'smart , driven , upbeat colleagues', 'leads way', 'Chain experience', 'responsible life', 'life cycle', 'successfully rolled', 'close relationships', 'involves close', 'close interaction', 'responsible life cycle product', 'closely - - market team', 'close relationships market', 'edge big', 'core makes', 'showing proven', 'thinking big', 'dive deep', 'deep details', 'dives deep', 'deep shown', 'customer - centric experience planet', 'high - growth , successful product launches', 'company Earth', 'driven people', 'owner universal', 'strong problem', 'having firm', 'working customer - centric company Earth', 'exceptionally talented , bright , dynamic , driven people', 'successful candidate highly analytical , data - driven , resourceful , customer - focused , ability work independently time constraints', 'workplace day', 'fair shot', 'shot success', 'power highly', 'Living Proof', 'fair shot success', 'rich set']
# ++++++++++++++++
# cluster 36 , values : ['individuals disabilities', 'disabilities like', 'disability', 'individuals', 'individual disability', 'physical mental', 'mental disabilities', 'status individual disability', 'applicants physical mental disabilities', 'mental sensory', 'sensory disability', 'protected disabilities', 'disabilities consistent', 'mental sensory disability', 'disabilities', 'disability employment', 'disability status', 'persons disabilities', 'disabilities provided', 'disability status category']
# ++++++++++++++++
# cluster 37 , values : ['dive technical', 'experience levels', 'knowledge sharing', 'ongoing learning', 'learning experiences', 'knowledge', 'passionate solving', 'highly analytical', 'analytical organized', 'strong technical', 'solid communication', 'communication skills', 'mentoring thorough', 'personal professional', 'strong technical business judgment solid communication skills', 'providing insights', 'technical acumen', 'acumen assess', 'foundational capabilities', 'deployment experience', 'architectural foundational capabilities', 'Machine Learning', 'Learning Deep', 'Deep Learning', 'solving hard', 'presentation skills', 'skills essential', 'superior analytical', 'analytical abilities', 'excellent technical', 'interaction communication', 'Machine Learning Deep Learning', 'product professional superior analytical abilities', 'excellent technical , problem - solving , team building , stakeholder interaction communication skills', 'focused approach', 'share expertise', 'expertise frontier', 'deep technical', 'technical knowledge', 'knowledge modern', 'solving future', 'strategic skills', 'analytical , strategic skills', 'experience support', 'strong understanding', 'technical background', 'strong technical background', 'looking Technical', 'Familiarity healthcare', 'machine learning', 'centric experience', 'challenging strategic', 'learning driven', 'solving skills', 'management skills', 'excellent communication', 'understanding developers', 'firm grasp', 'grasp operational', 'technical aspects', 'functional experience', 'strong problem - solving skills', 'product management skills', 'excellent communication skills', 'firm grasp operational , strategic , technical aspects product', 'expertise solving', 'solving problems', 'learning SophosLabs']
# ++++++++++++++++
# cluster 38 , values : ['fully managed', 'opportunity collaborate', 'able collaborate', 'collaborate effectively', 'effectively diverse', 'retrieve', 'partners integrate', 'role interact', 'interact levels', 'strive assign', 'assign projects', 'enable complex', 'tasks future', 'insights optimize', 'optimize costs', 'role leverage', 'leverage extend', 'define deliver', 'capabilities easier', 'execute cross', 'place evaluate', 'allowing flexibility', 'continue evolve', 'initiatives automate', 'automate drive', 'way manage', 'Define Future', 'deliver disruptive', 'fundamentally rewrite', 'magnify impact', 'analytics efforts', 'efforts solve', 'remotely advised', 'assist users', 'directly collaborate', 'collaborate core', 'leverage single', 'manage app', 'leverage', 'plan successfully', 'ability speak', 'ability', 'quickly efficiently', 'efficiently query', 'interactively growing', 'maintain enhance', 'opportunity interact', 'identify hidden', 'tools protect', 'possess ability', 'ability influence', 'able manage', 'manage complex', 'create certainty', 'analyze use']
# ++++++++++++++++
# cluster 39 , values : ['premises data', 'data centers', 'retrieve data', 'Enterprise Data', 'Data Services', 'future data', 'data issues', 'protecting data', 'data sources', 'Data Protection', 'cloud data', 'data protection', 'Data Protection Group', 'applicant data', 'data submitted', 'compute', 'Alexa Data', 'truth data', 'data Alexa', 'edge data', 'data science', 'measuring metrics', 'metrics monitoring', 'Alexa Data Services', 'ground truth data', 'metrics', 'Global Data', 'Data Privacy', 'General Data', 'manage data', 'data job', 'outlining data', 'data processed', 'processing data', 'data required', 'PM Data', 'Data Infrastructure', 'Benchling data', 'data warehouse', 'internal data', 'data architecture', 'data analysts', 'analysts user', 'modern data', 'data systems', 'PM Data Infrastructure', 'data warehouse internal data architecture', 'internal data analysts user base', 'modern data systems', 'Compute', 'services data', 'data pipeline', 'big data', 'insights data', 'data serverless', 'SQL query', 'Data customers', 'query analyze', 'petabytes data', 'data interactively', 'data S3', 'relational databases', 'data stores', 'data serverless SQL query service', 'data stores seconds', 'data scientists', 'data scientists org', 'behavioral data', 'data power', 'data marketing', 'valuable data', 'data popular', 'centralized data', 'data lake', 'centralized data lake']
# ++++++++++++++++
# cluster 40 , values : ['leader Software', 'protection software', 'software market', 'multi cloud data protection software market', 'advances software', 'latest advances software', 'based VMware', 'VMware Company', 'believe software', 'software power', 'security software', 'software form', 'delivering apps', 'VMware based', 'Vmware provide', 'VMware Company Overview', 'compatible site', 'click download', 'download free', 'free compatible', 'compatible screen', 'screen reader', 'technology compatible site', 'free compatible screen reader', 'Gene editing', 'editing cell', 'modern software', 'Cambridge Mobile', 'mobile usage', 'Powered mobile', 'users crashes', 'software pioneer', 'Nutanix software', 'software leverage', 'Nutanix global leader cloud software pioneer', 'create software', 'software solutions', 'computer vision', 'query engine', 'engine tick', 'query engine tick', 'tech ad', 'Custom Ink', 'malware']
# ++++++++++++++++
# cluster 41 , values : ['infrastructure services', 'services customers', 'scaled services', 'Security Services', 'applications services', 'security services', 'services like', 'services focused', 'cross service', 'service integration', 'services external', 'quality services', 'cloud security services', 'innovative security services', 'comprehensive security', 'security offering', 'comprehensive security offering identity', 'easier services', 'services integration', 'easier services integration', 'services experiences', 'military service', 'present military service', 'service scale', 'Services LLC', 'analytics provider', 'provider insurers', 'safety providers', 'telematics services', 'personal safety providers', 'deliver services', 'services redefine', 'managed services', 'services delivery', 'services', 'distributed services', 'services secure', 'services reseller', 'managed service', 'service providers']
# ++++++++++++++++
# cluster 42 , values : ['passionate delivering', 'furthering culture', 'including Conversations', 'Conversations Race', 'seek diverse', 'diverse perspectives', 'chapters', 'closely dozens', 'represents deeply', 'deeply passionate', 'happiness fulfillment', 'personal lives', 'Centered privileged', 'uniqueness know', 'know diverse', 'insights', 'myriad needs', 'delivering world', 'people planet', 'experiences transforming', 'people deeply', 'deeply value', 'passion', 'Description passionate', 'passionate Artificial', 'pioneering shaping', 'shaping world', 'enjoys innovating', 'mainstream awareness', 'economic freedom', 'freedom world', 'thrive culture', 'culture like', 'embrace feedback', 'people desire', 'know nature', 'economic freedom world', 'ethical food', 'solve humanity', 'humanity pressing', 'world renowned', 'broadening ways', 'humanity', 'mission world', 'Nutanix passionate', 'share intellectual', 'intellectual curiosity', 'entrepreneurial spirit', 'humbled recognized', 'fundamentally betters', 'betters world', 'upbeat colleagues', 'colleagues unique', 'unique backgrounds', 'backgrounds interests', 'fundamentally betters world', 'unique backgrounds interests', 'realize vision', 'vision revolutionize', 'speak fluently', 'obsessed delivering', 'experience planet', 'sharing vision', 'ideas reality', 'party fulfillment', 'source truth', 'influence people', 'mindset bringing', 'experiences perspectives', 'perspectives Klaviyo', 'appreciate experiences', 'experiences person', 'Klaviyo value unique backgrounds , experiences perspectives', 'exploits']
# ++++++++++++++++
# cluster 43 , values : ['delivering solutions', 'innovative security', 'variety technologies', 'technologies capabilities', 'integrated technology', 'capabilities market', 'heterogeneous infrastructure', 'infrastructure roadmap', 'infrastructure', 'networking', 'infrastructure solutions', 'solutions enables', 'ways technologies', 'technologies work', 'technologies', 'edge technology', 'frontier technologies', 'technologies crypto', 'reading technology', 'technology compatible', 'industry technology', 'disruptive solutions', 'central technology', 'technology use', 'Mobile Telematics', 'providing telematics', 'computing industry', 'solutions deliver', 'integration technologies', 'technologies streamline', 'chain solutions', 'development solutions', 'retail catalogues integration technologies', 'owns technology', 'interactive technology', 'technology serve', 'deploy infrastructure', 'infrastructure applications', 'portfolio advanced']
# ++++++++++++++++
# cluster 44 , values : ['enabling customers', 'customers store', 'solutions customers', 'customers excited', 'delight customers', 'customers', 'user experience', 'solving customer', 'customer problems', 'ambiguous customer', 'customer needs', 'roadmap customers', 'applications customers', 'customers love', 'work customers', 'naturally customer', 'ambiguous customer needs', 'disruptive , successful products delight customers', 'impact work customers', 'customer - centric', 'VPC customers', 'external customers', 'SMB customers', 'customers thrive', 'class customer', 'customer experience', 'Subscription offerings', 'world class customer experience SaaS Subscription offerings', 'Customer personas', 'platform service scale product Customer personas', 'easy consumers', 'consumers access', 'customers include', 'Benchling customers', 'customers internal', 'obsession customers', 'key customers', 'helping customers', 'customers insights', 'customers need', 'possible customers', 'delivering customer', 'new customers', 'customers features', 'driving customer', 'customer success', 'working customer', 'customers want', 'ensuring customers', 'customers safe', 'environment customer', 'customer safety', 'enable customers', 'customers find', 'enhance customer', 'customer trust', 'protect customers', 'problems customer', 'revenue customer', 'customer connection', 'targeted customer', 'customer prospect', 'relationships customers', 'best product possible customers', 'customer - mindset', 'dedicated accelerating revenue customer connection', 'direct relationships customers', 'available customers', 'reseller partners']
# ++++++++++++++++
# cluster 45 , values : ['care causes', 'including pregnancy', 'related medical', 'medical conditions', 'pregnancy', 'childbirth', 'related medical conditions', 'family medical', 'medical history', 'genetic information', 'family medical history genetic information', 'cell therapy', 'therapy dramatically', 'treat cancer', 'cancer major', 'major illnesses', 'Gene editing cell therapy', 'treat cancer major illnesses', 'problems', 'proof vaccination', 'vaccination prior', 'approved medical', 'medical religious', 'revolutionize treatment', 'treatment gastrointestinal', 'gastrointestinal diseases', 'diseases computer', 'treatment gastrointestinal diseases computer vision']
# ++++++++++++++++
# cluster 46 , values : ['business development', 'strategic roadmap', 'roadmap business', 'business development teams', 'strategic roadmap business', 'new business', 'business opportunity', 'technical business', 'business judgment', 'new business opportunity', 'business applications', 'extend business', 'business technical', 'business technical acumen', 'strategy', 'business strategy', 'Company Overview', 'transforming business', 'business innovation', 'based business', 'business needs', 'Marketing Product Management Manager Professional Time', 'enterprise', 'business strategy product operations', 'Marketing Product Management Manager', 'business innovation globe', 'believe business', 'business force', 'enterprise programs', 'superior business', 'business judgement', 'superior business judgement', 'marketing', 'way Enterprise', 'Enterprise Information', 'portfolio Business', 'Business Network', 'Network business', 'business unit', 'requirements business', 'business plan', 'drive Business', 'Network strategy', 'streamline business', 'business processes', 'strategic plan', 'Enterprise Information Management', 'Active Applications portfolio Business Network business unit', 'product roadmap meet requirements business plan', 'Lead Product Manager drive Business Network strategy', 'strong business', 'business owners', 'business cases', 'strong business owners', 'strong business cases', 'centric company', 'retail business', 'fulfillment business', 'leadership business', 'business managers', 'numerous business', 'business models', 'tech strategy', 'tech leadership business managers', 'numerous business models', 'leading marketing', 'marketing automation', 'online businesses', 'based management']
# ++++++++++++++++
# cluster 47 , values : ['legally protected', 'protected status', 'protected veteran status', ', legally protected status', 'protection', 'protected reason', 'status protected', 'applicable legally', 'protected characteristics', 'handled accordance', 'accordance Applicant', 'Applicant Privacy', 'Privacy Policy', 'medical , religious , legally protected reason', 'applicable legally protected characteristics', 'accordance Applicant Privacy Policy', 'effectively mandates', 'subject legally', 'legally required', 'requirements individual', 'protected laws', 'laws regulations', 'regulations locations', 'subject legally required accommodations', 'laws regulations locations', 'consistent local law', 'basis protected', 'protected applicable', 'applicable law', 'consistent applicable', 'applicable federal', 'Law notices', 'required law', 'Privacy Notice', 'Protection Regulation', 'Consumer Privacy', 'Privacy Act', 'procedure applicable', 'applicable locations', 'consistent applicable federal , state local law', 'Requirements', 'category protected', 'ensure persons', 'meet requirements', 'simply complying', 'complying applicable', 'applicable laws', 'religious exemptions', 'qualify exemption', 'exemption request', 'request exemption', 'exemption form', 'approved medical religious exemptions', 'qualify exemption request exemption form', 'safety compliance', 'compliance safety', 'ambiguous requirements', 'legal respective', 'certainty ambiguous requirements']
# ++++++++++++++++
# cluster 48 , values : ['based applications', 'processed application', 'application procedure', 'submitting application', 'use processing', 'data processed application procedure applicable locations', 'application', 'Benchling applications', 'Active Applications', 'Applications portfolio']
# ++++++++++++++++
# cluster 49 , values : ['Veritas SaaS', 'SaaS Backup', 'NetBackup SaaS', 'SaaS Protection', 'Veritas SaaS Backup', 'NetBackup SaaS Protection Backup Exec', 'SaaS VPC', 'SaaS VPC customers', 'experience SaaS', 'SaaS Subscription', 'VMware SaaS', 'SaaS Transformation', 'obsessed SaaS', 'SaaS company', 'VMware SaaS Transformation', 'SaaS solutions']
# ++++++++++++++++
